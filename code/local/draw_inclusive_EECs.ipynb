# %% [markdown]
# Normalises and draws the inclusive EECs

# %%
import ROOT
import numpy as np
import math
import matplotlib.pyplot as plt
import os
import ctypes
import array

# %%
ROOT.gDirectory.Clear()
filepath_0mb_inc = "/Users/rohanjagadeesan/Desktop/Code/li_lab/EnergyCorrelators/output/0mb_inclusive/EEC_non_binned_Output_Batch0.root"
filepath_3mb_inc = "/Users/rohanjagadeesan/Desktop/Code/li_lab/EnergyCorrelators/output/3mb_inclusive/EEC_non_binned_Output_Batch0.root"

# %%
# get and normalise the histograms

def initialise(filepath1, filepath2):
    '''
    returns normalised EECs
    '''

    tfile1 = ROOT.TFile.Open(filepath1, "READ")
    num_jets1 = tfile1.Get("num_jets_STD").GetVal()
    EEC1 = tfile1.Get("hEEC_STD")
    EEC1.SetDirectory(0)
    EEC1.Scale(1/num_jets1)
    tfile1.Close()

    tfile2 = ROOT.TFile.Open(filepath2, "READ")
    num_jets2 = tfile2.Get("num_jets_STD").GetVal()
    EEC2 = tfile2.Get("hEEC_STD")
    EEC2.SetDirectory(0)
    EEC2.Scale(1/num_jets2)
    tfile2.Close()

    return EEC1, EEC2

# %%
colours = [ROOT.kBlue+1, ROOT.kMagenta+1, ROOT.kSpring+4, ROOT.kRed+1, ROOT.kOrange+7]

# %% [markdown]
# # EEC plots

# %%
# log version, no markers

ROOT.gDirectory.Clear()

eec_0mb , eec_3mb = initialise(filepath_0mb_inc, filepath_3mb_inc)

# make TGraphErrors
tgraph_eec_0mb = ROOT.TGraphErrors(eec_0mb)
tgraph_eec_3mb = ROOT.TGraphErrors(eec_3mb)

# Choosing colours:
tgraph_eec_0mb.SetLineColorAlpha(colours[0], 0.7)
tgraph_eec_3mb.SetLineColorAlpha(colours[4], 0.7)

tgraph_eec_0mb.SetLineWidth(2)
tgraph_eec_3mb.SetLineWidth(2)

tgraph_eec_0mb.SetMarkerColorAlpha(colours[0], 0.7)
tgraph_eec_3mb.SetMarkerColorAlpha(colours[4], 0.7)

# if you don't want markers:
tgraph_eec_0mb.SetMarkerStyle(1)
tgraph_eec_3mb.SetMarkerStyle(1)

tgraph_eec_0mb.SetMarkerSize(0)
tgraph_eec_3mb.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l", "log EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
# no error bars version:
mg.Add(tgraph_eec_0mb, "CX")
mg.Add(tgraph_eec_3mb, "CX")

# title
mg.SetTitle("EEC for inclusive datasets; #Delta R_{L}; E2C")
mg.Draw("A") 

# Log scale axes
canvas.SetLogx(1)
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

# Legend setup
legend = ROOT.TLegend(0.28, 0.28, 0.68, 0.48) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_eec_0mb, "0mb", "L")
legend.AddEntry(tgraph_eec_3mb, "3.0mb", "L")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_inclusive_log_plot.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_inclusive_log_plot.pdf has been created

# %%
# nonlog version, no markers

ROOT.gDirectory.Clear()

eec_0mb , eec_3mb = initialise(filepath_0mb_inc, filepath_3mb_inc)

# make TGraphErrors
tgraph_eec_0mb = ROOT.TGraphErrors(eec_0mb)
tgraph_eec_3mb = ROOT.TGraphErrors(eec_3mb)

# Choosing colours:
tgraph_eec_0mb.SetLineColorAlpha(colours[0], 0.7)
tgraph_eec_3mb.SetLineColorAlpha(colours[4], 0.7)

tgraph_eec_0mb.SetLineWidth(2)
tgraph_eec_3mb.SetLineWidth(2)

tgraph_eec_0mb.SetMarkerColorAlpha(colours[0], 0.7)
tgraph_eec_3mb.SetMarkerColorAlpha(colours[4], 0.7)

# if you don't want markers:
tgraph_eec_0mb.SetMarkerStyle(1)
tgraph_eec_3mb.SetMarkerStyle(1)

tgraph_eec_0mb.SetMarkerSize(0)
tgraph_eec_3mb.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l", "log EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
# no error bars version:
mg.Add(tgraph_eec_0mb, "CX")
mg.Add(tgraph_eec_3mb, "CX")

# title
mg.SetTitle("EEC for inclusive datasets; #Delta R_{L}; E2C")
mg.Draw("A") 

#scale axes
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

# Legend setup
legend = ROOT.TLegend(0.28, 0.28, 0.68, 0.48) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_eec_0mb, "0mb", "L")
legend.AddEntry(tgraph_eec_3mb, "3.0mb", "L")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_inclusive_nonlog_plot.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_inclusive_nonlog_plot.pdf has been created

# %%
# log version, with markers

ROOT.gDirectory.Clear()

eec_0mb , eec_3mb = initialise(filepath_0mb_inc, filepath_3mb_inc)

# make TGraphErrors
tgraph_eec_0mb = ROOT.TGraphErrors(eec_0mb)
tgraph_eec_3mb = ROOT.TGraphErrors(eec_3mb)

# Choosing colours:
tgraph_eec_0mb.SetLineColorAlpha(colours[0], 0.5)
tgraph_eec_3mb.SetLineColorAlpha(colours[4], 0.5)

tgraph_eec_0mb.SetMarkerColorAlpha(colours[0], 0.7)
tgraph_eec_3mb.SetMarkerColorAlpha(colours[4], 0.7)

# markers:
tgraph_eec_0mb.SetMarkerStyle(20)
tgraph_eec_3mb.SetMarkerStyle(20)

tgraph_eec_0mb.SetMarkerSize(0.4)
tgraph_eec_3mb.SetMarkerSize(0.4)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l", "log EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_eec_0mb, "PE")
mg.Add(tgraph_eec_3mb, "PE")

# title
mg.SetTitle("EEC for inclusive datasets; #Delta R_{L}; E2C")
mg.Draw("A") 

# Log scale axes
canvas.SetLogx(1)
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

# Legend setup
legend = ROOT.TLegend(0.28, 0.28, 0.68, 0.48) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_eec_0mb, "0mb", "PE")
legend.AddEntry(tgraph_eec_3mb, "3.0mb", "PE")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_inclusive_log_plot_markers.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_inclusive_log_plot_markers.pdf has been created

# %%
# nonlog version, with markers

ROOT.gDirectory.Clear()

eec_0mb , eec_3mb = initialise(filepath_0mb_inc, filepath_3mb_inc)

# make TGraphErrors
tgraph_eec_0mb = ROOT.TGraphErrors(eec_0mb)
tgraph_eec_3mb = ROOT.TGraphErrors(eec_3mb)

# Choosing colours:
tgraph_eec_0mb.SetLineColorAlpha(colours[0], 0.5)
tgraph_eec_3mb.SetLineColorAlpha(colours[4], 0.5)

tgraph_eec_0mb.SetMarkerColorAlpha(colours[0], 0.7)
tgraph_eec_3mb.SetMarkerColorAlpha(colours[4], 0.7)

# markers:
tgraph_eec_0mb.SetMarkerStyle(20)
tgraph_eec_3mb.SetMarkerStyle(20)

tgraph_eec_0mb.SetMarkerSize(0.4)
tgraph_eec_3mb.SetMarkerSize(0.4)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l", "log EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_eec_0mb, "PE")
mg.Add(tgraph_eec_3mb, "PE")

# title
mg.SetTitle("EEC for inclusive datasets; #Delta R_{L}; E2C")
mg.Draw("A") 

# Log scale axes
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

# Legend setup
legend = ROOT.TLegend(0.28, 0.28, 0.68, 0.48) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_eec_0mb, "0mb", "PE")
legend.AddEntry(tgraph_eec_3mb, "3.0mb", "PE")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_inclusive_nonlog_plot_markers.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_inclusive_nonlog_plot_markers.pdf has been created

# %%
# log version, with markers, forced y axis

ROOT.gDirectory.Clear()

eec_0mb , eec_3mb = initialise(filepath_0mb_inc, filepath_3mb_inc)

# make TGraphErrors
tgraph_eec_0mb = ROOT.TGraphErrors(eec_0mb)
tgraph_eec_3mb = ROOT.TGraphErrors(eec_3mb)

# Choosing colours:
tgraph_eec_0mb.SetLineColorAlpha(colours[0], 0.5)
tgraph_eec_3mb.SetLineColorAlpha(colours[4], 0.5)

tgraph_eec_0mb.SetMarkerColorAlpha(colours[0], 0.7)
tgraph_eec_3mb.SetMarkerColorAlpha(colours[4], 0.7)

# markers:
tgraph_eec_0mb.SetMarkerStyle(20)
tgraph_eec_3mb.SetMarkerStyle(20)

tgraph_eec_0mb.SetMarkerSize(0.4)
tgraph_eec_3mb.SetMarkerSize(0.4)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l", "log EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_eec_0mb, "PE")
mg.Add(tgraph_eec_3mb, "PE")

# title
mg.SetTitle("EEC for inclusive datasets; #Delta R_{L}; E2C")
mg.Draw("A") 

# Log scale axes
canvas.SetLogx(1)
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)

mg.SetMaximum(1)
mg.SetMinimum(0.0001)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

# Legend setup
legend = ROOT.TLegend(0.28, 0.28, 0.68, 0.48) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_eec_0mb, "0mb", "PE")
legend.AddEntry(tgraph_eec_3mb, "3.0mb", "PE")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_inclusive_log_plot_forced_markers.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_inclusive_log_plot_forced_markers.pdf has been created

# %% [markdown]
# # ratio

# %%
# log version of ratio, with markers

ROOT.gDirectory.Clear()

eec_0mb , ratio_eecs = initialise(filepath_0mb_inc, filepath_3mb_inc)

# get ratio
ratio_eecs.Divide(eec_0mb)

# make TGraphErrors
tgraph_ratio = ROOT.TGraphErrors(ratio_eecs)

# Choosing colours:
tgraph_ratio.SetLineColorAlpha(colours[0], 0.7)

tgraph_ratio.SetMarkerColorAlpha(colours[0], 0.7)

# markers:
tgraph_ratio.SetMarkerStyle(20)

tgraph_ratio.SetMarkerSize(0.8)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l_r", "log ratio of EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_ratio, "PE")

# title
mg.SetTitle("Ratio of EECs for inclusive datasets; #Delta R_{L}; E2C_{3.0mb} / E2C_{0mb}")
mg.Draw("A") 

# reference line
line = ROOT.TLine(0, 1.0, 1.0, 1.0)
line.SetLineStyle(2) # Dashed configuration
line.SetLineColor(ROOT.kBlack)
line.Draw()

# scale axes
canvas.SetLogx(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0, 2)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)


# Legend setup
legend = ROOT.TLegend(0.28, 0.78, 0.48, 0.88) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_ratio, "Ratio of EECs", "PE")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_inclusive_ratio_log_markers.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_inclusive_ratio_log_markers.pdf has been created

# %%
# non log version of ratio, with markers

ROOT.gDirectory.Clear()

eec_0mb , ratio_eecs = initialise(filepath_0mb_inc, filepath_3mb_inc)

# get ratio
ratio_eecs.Divide(eec_0mb)

# make TGraphErrors
tgraph_ratio = ROOT.TGraphErrors(ratio_eecs)

# Choosing colours:
tgraph_ratio.SetLineColorAlpha(colours[0], 0.7)

tgraph_ratio.SetMarkerColorAlpha(colours[0], 0.7)

# markers:
tgraph_ratio.SetMarkerStyle(20)

tgraph_ratio.SetMarkerSize(0.8)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l_r", "ratio of EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_ratio, "PE")

# title
mg.SetTitle("Ratio of EECs for inclusive datasets; #Delta R_{L}; E2C_{3.0mb} / E2C_{0mb}")
mg.Draw("A") 

# reference line
line = ROOT.TLine(0, 1.0, 1.0, 1.0)
line.SetLineStyle(2) # Dashed configuration
line.SetLineColor(ROOT.kBlack)
line.Draw()

# scale axes
mg.GetXaxis().SetLimits(0, 1.0)
mg.GetYaxis().SetLimits(0, 2)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)


# Legend setup
legend = ROOT.TLegend(0.28, 0.78, 0.48, 0.88) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_ratio, "Ratio of EECs", "PE")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_inclusive_ratio_nonlog_markers.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_inclusive_ratio_nonlog_markers.pdf has been created

# %%
# log version of ratio, without markers

ROOT.gDirectory.Clear()

eec_0mb , ratio_eecs = initialise(filepath_0mb_inc, filepath_3mb_inc)

# get ratio
ratio_eecs.Divide(eec_0mb)

# make TGraphErrors
tgraph_ratio = ROOT.TGraphErrors(ratio_eecs)

# Choosing colours:
tgraph_ratio.SetLineColorAlpha(colours[0], 0.8)
tgraph_ratio.SetMarkerColorAlpha(colours[0], 0.7)

# markers:
tgraph_ratio.SetMarkerStyle(1)
tgraph_ratio.SetMarkerSize(0)
tgraph_ratio.SetLineWidth(1)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l_r", "log ratio of EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_ratio, "LX")

# title
mg.SetTitle("Ratio of EECs for inclusive datasets; #Delta R_{L}; E2C_{3.0mb} / E2C_{0mb}")
mg.Draw("A") 

# reference line
line = ROOT.TLine(0, 1.0, 1.0, 1.0)
line.SetLineStyle(2) # Dashed configuration
line.SetLineColor(ROOT.kBlack)
line.Draw()

# scale axes
canvas.SetLogx(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0, 2)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)


# Legend setup
legend = ROOT.TLegend(0.28, 0.80, 0.48, 0.88) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_ratio, "Ratio of EECs", "L")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_inclusive_ratio_log_smooth.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_inclusive_ratio_log_smooth.pdf has been created

# %%
# nonlog version of ratio, without markers

ROOT.gDirectory.Clear()

eec_0mb , ratio_eecs = initialise(filepath_0mb_inc, filepath_3mb_inc)

# get ratio
ratio_eecs.Divide(eec_0mb)

# make TGraphErrors
tgraph_ratio = ROOT.TGraphErrors(ratio_eecs)

# Choosing colours:
tgraph_ratio.SetLineColorAlpha(colours[0], 0.8)
tgraph_ratio.SetMarkerColorAlpha(colours[0], 0.7)

# markers:
tgraph_ratio.SetMarkerStyle(1)
tgraph_ratio.SetMarkerSize(0)
tgraph_ratio.SetLineWidth(1)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l_r", "log ratio of EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_ratio, "LX")

# title
mg.SetTitle("Ratio of EECs for inclusive datasets; #Delta R_{L}; E2C_{3.0mb} / E2C_{0mb}")
mg.Draw("A") 

# reference line
line = ROOT.TLine(0, 1.0, 1.0, 1.0)
line.SetLineStyle(2) # Dashed configuration
line.SetLineColor(ROOT.kBlack)
line.Draw()

# scale axes
mg.GetXaxis().SetLimits(0, 1.0)
mg.GetYaxis().SetLimits(0, 2)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)


# Legend setup
legend = ROOT.TLegend(0.28, 0.80, 0.48, 0.88) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_ratio, "Ratio of EECs", "L")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_inclusive_ratio_nonlog_smooth.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_inclusive_ratio_nonlog_smooth.pdf has been created

# %%
# nonlog version of ratio, without markers - FORCED Y AXIS

ROOT.gDirectory.Clear()

eec_0mb , ratio_eecs = initialise(filepath_0mb_inc, filepath_3mb_inc)

# get ratio
ratio_eecs.Divide(eec_0mb)

# make TGraphErrors
tgraph_ratio = ROOT.TGraphErrors(ratio_eecs)

# Choosing colours:
tgraph_ratio.SetLineColorAlpha(colours[0], 0.8)
tgraph_ratio.SetMarkerColorAlpha(colours[0], 0.7)

# markers:
tgraph_ratio.SetMarkerStyle(1)
tgraph_ratio.SetMarkerSize(0)
tgraph_ratio.SetLineWidth(1)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l_r", "log ratio of EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_ratio, "LX")

# title
mg.SetTitle("Ratio of EECs for inclusive datasets; #Delta R_{L}; E2C_{3.0mb} / E2C_{0mb}")
mg.Draw("A") 

# reference line
line = ROOT.TLine(0, 1.0, 1.0, 1.0)
line.SetLineStyle(2) # Dashed configuration
line.SetLineColor(ROOT.kBlack)
line.Draw()

# scale axes
mg.GetXaxis().SetLimits(0, 1.0)
mg.GetYaxis().SetLimits(0, 2)
mg.SetMaximum(2)
mg.SetMinimum(0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)


# Legend setup
legend = ROOT.TLegend(0.28, 0.80, 0.48, 0.88) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_ratio, "Ratio of EECs", "L")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_inclusive_ratio_forced_nonlog_smooth.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_inclusive_ratio_forced_nonlog_smooth.pdf has been created

# %%
# log version of ratio, without markers, FORCED Y AXIS

ROOT.gDirectory.Clear()

eec_0mb , ratio_eecs = initialise(filepath_0mb_inc, filepath_3mb_inc)

# get ratio
ratio_eecs.Divide(eec_0mb)

# make TGraphErrors
tgraph_ratio = ROOT.TGraphErrors(ratio_eecs)

# Choosing colours:
tgraph_ratio.SetLineColorAlpha(colours[0], 0.8)
tgraph_ratio.SetMarkerColorAlpha(colours[0], 0.7)

# markers:
tgraph_ratio.SetMarkerStyle(1)
tgraph_ratio.SetMarkerSize(0)
tgraph_ratio.SetLineWidth(1)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l_r", "log ratio of EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_ratio, "LX")

# title
mg.SetTitle("Ratio of EECs for inclusive datasets; #Delta R_{L}; E2C_{3.0mb} / E2C_{0mb}")
mg.Draw("A") 

# reference line
line = ROOT.TLine(0, 1.0, 1.0, 1.0)
line.SetLineStyle(2) # Dashed configuration
line.SetLineColor(ROOT.kBlack)
line.Draw()

# scale axes
canvas.SetLogx(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0, 2)
mg.SetMaximum(2)
mg.SetMinimum(0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)


# Legend setup
legend = ROOT.TLegend(0.28, 0.80, 0.48, 0.88) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_ratio, "Ratio of EECs", "L")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_inclusive_ratio_forced_log_smooth.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_inclusive_ratio_forced_log_smooth.pdf has been created

# %% [markdown]
# # rebinning

# %%
def rebin_nonlog(hist1, hist2, name1, name2, numbins):
    '''
    input: 
    - the eec histograms returned by initialise(filepath1, filepath2)
    - the names of the histograms (strings)
    - number of bins to merge into 1

    output: rebinned nonlog versions of the histograms
    '''

    h1_rebinned = hist1.Rebin(numbins, f"{name1};#Delta R;EEC", 0)
    h2_rebinned = hist2.Rebin(numbins, f"{name2};#Delta R;EEC", 0)

    return h1_rebinned, h2_rebinned



def rebin_log(hist, name, num_bins_target=50):
    '''
    input: 
    - the ratio histogram
    - the name of the new rebinned histograms
    - the desired number of logarithmic bins
    
    output: rebinned log-spaced versions of the histograms
    '''
    import array
    
    # 1. Define the limits (your histograms range from 0 to 1)
    # Since log(0) is undefined, start slightly above 0 matching your plot limits (e.g., 10^-3)
    xmin = 0.001
    xmax = 1.0
    
    # 2. Generate log-spaced bin edges using numpy
    # logspace arguments are the exponents: 10^-3 to 10^0
    bin_edges_np = np.logspace(math.log10(xmin), math.log10(xmax), num_bins_target + 1)
    
    # 3. Convert the numpy array to a standard Python/C-compatible array for ROOT
    bin_edges_array = array.array('d', bin_edges_np)
    
    # 4. Create new empty histograms with variable bin widths
    new_hist = ROOT.TH1D(name, f"{hist.GetTitle()};#Delta R;EEC", num_bins_target, bin_edges_array)
    
    # Ensure Sumw2 is enabled to compute correct errors for variable bin widths
    new_hist.Sumw2()
    
    # 5. Manually remap the bin contents from the old fine linear bins to the new log bins
    # We loop over the fine uniform bins of the original histogram
    for old_bin in range(1, hist.GetNbinsX() + 1):
        bin_center = hist.GetBinCenter(old_bin)
        
        # Skip values below our log starting threshold to prevent underflow clutter
        if bin_center < xmin:
            continue
            
        bin_content = hist.GetBinContent(old_bin)
        bin_error = hist.GetBinError(old_bin)
        
        # Find which log-bin this center falls into
        new_bin = new_hist.FindBin(bin_center)
        
        # Add content and propagate errors in quadrature
        new_hist.SetBinContent(new_bin, new_hist.GetBinContent(new_bin) + bin_content)
        new_hist.SetBinError(new_bin, math.sqrt(new_hist.GetBinError(new_bin)**2 + bin_error**2))
        
    return new_hist

# %%
xmin = 0.001
xmax = 1
num_bins_target = 50
bin_edges_np = np.logspace(math.log10(xmin), math.log10(xmax), num_bins_target + 1)

print(bin_edges_np)

for i in range(len(bin_edges_np) - 1):
    print(bin_edges_np[i+1] - bin_edges_np[i])
# Out:
# [0.001      0.00114815 0.00131826 0.00151356 0.0017378  0.00199526
#  0.00229087 0.00263027 0.00301995 0.00346737 0.00398107 0.00457088
#  0.00524807 0.0060256  0.00691831 0.00794328 0.00912011 0.01047129
#  0.01202264 0.01380384 0.01584893 0.01819701 0.02089296 0.02398833
#  0.02754229 0.03162278 0.03630781 0.04168694 0.04786301 0.05495409
#  0.06309573 0.0724436  0.08317638 0.09549926 0.10964782 0.12589254
#  0.14454398 0.16595869 0.19054607 0.21877616 0.25118864 0.28840315
#  0.33113112 0.3801894  0.43651583 0.50118723 0.57543994 0.66069345
#  0.75857758 0.87096359 1.        ]
# 0.00014815362149688286
# 0.00017010311705952462
# 0.00019530450987980123
# 0.00022423958031316752
# 0.00025746148621950266
# 0.00029560533779889346
# 0.0003394003391276089
# 0.00038968372850663483
# 0.00044741678412330054
# 0.0005137032010096567
# 0.0005898101906137787
# 0.0006771927063489707
# 0.0007775212582458576
# 0.0008927138484457822
# 0.001024972638053451
# 0.001176826046316283
# 0.001351177086949899
# 0.001551358865665136
# 0.0017811982998547134
# 0.002045089278582289
# 0.0023480766614887016
# 0.00269595272244055
# 0.0030953678816545115
# 0.0035539578431867634
# 0.004080489568302131
# 0.004685028875326347
# 0.005379132870023388
# 0.006176070885230298
# 0.007091078153498631
# 0.008141647062256847
# 0.009347861559479684
# 0.010732781102768096
# 0.012322881491876506
# 0.014148561012174918
# 0.01624472156509825
# 0.01865143589517604
# 0.02141471366916317
# 0.024587381052568663
# 0.028230090598630547
# 0.03241248075600278
# 0.037214507161702604
# 0.042727971169930545
# 0.04905827483797015
# 0.0563264359196044
# 0.06467140138710636
# 0.07425270370988457
# 0.08525351067043918
# 0.09788412702158777
# 0.11238601492689693
# 0.12903641004391952

# %% [markdown]
# ## EEC plots

# %%
# nonlog version, with markers

ROOT.gDirectory.Clear()

eec_0mb , eec_3mb = initialise(filepath_0mb_inc, filepath_3mb_inc)

eec_0mb_rebinned, eec_3mb_rebinned = rebin_nonlog(eec_0mb, eec_3mb, "0mb_rebinned_nonlog", "3mb_rebinned_nonlog", 10)


# make TGraphErrors
tgraph_eec_0mb = ROOT.TGraphErrors(eec_0mb_rebinned)
tgraph_eec_3mb = ROOT.TGraphErrors(eec_3mb_rebinned)

# Choosing colours:
tgraph_eec_0mb.SetLineColorAlpha(colours[0], 0.5)
tgraph_eec_3mb.SetLineColorAlpha(colours[4], 0.5)

tgraph_eec_0mb.SetMarkerColorAlpha(colours[0], 0.7)
tgraph_eec_3mb.SetMarkerColorAlpha(colours[4], 0.7)

# markers:
tgraph_eec_0mb.SetMarkerStyle(20)
tgraph_eec_3mb.SetMarkerStyle(20)

tgraph_eec_0mb.SetMarkerSize(0.4)
tgraph_eec_3mb.SetMarkerSize(0.4)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l", "nonlog EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_eec_0mb, "PE")
mg.Add(tgraph_eec_3mb, "PE")

# title
mg.SetTitle("EEC for inclusive datasets; #Delta R_{L}; E2C")
mg.Draw("A") 

# Log scale axes
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

# Legend setup
legend = ROOT.TLegend(0.28, 0.28, 0.68, 0.48) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_eec_0mb, "0mb", "PE")
legend.AddEntry(tgraph_eec_3mb, "3.0mb", "PE")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_rebinned_inclusive_nonlog_plot_markers.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_rebinned_inclusive_nonlog_plot_markers.pdf has been created

# %%
# log version, with markers

ROOT.gDirectory.Clear()

eec_0mb , eec_3mb = initialise(filepath_0mb_inc, filepath_3mb_inc)

# make TGraphErrors
tgraph_eec_0mb = ROOT.TGraphErrors(eec_0mb)
tgraph_eec_3mb = ROOT.TGraphErrors(eec_3mb)

# Choosing colours:
tgraph_eec_0mb.SetLineColorAlpha(colours[0], 0.5)
tgraph_eec_3mb.SetLineColorAlpha(colours[4], 0.5)

tgraph_eec_0mb.SetMarkerColorAlpha(colours[0], 0.7)
tgraph_eec_3mb.SetMarkerColorAlpha(colours[4], 0.7)

# markers:
tgraph_eec_0mb.SetMarkerStyle(20)
tgraph_eec_3mb.SetMarkerStyle(20)

tgraph_eec_0mb.SetMarkerSize(0.4)
tgraph_eec_3mb.SetMarkerSize(0.4)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l", "log EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_eec_0mb, "PE")
mg.Add(tgraph_eec_3mb, "PE")

# title
mg.SetTitle("EEC for inclusive datasets; #Delta R_{L}; E2C")
mg.Draw("A") 

# Log scale axes
canvas.SetLogx(1)
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

# Legend setup
legend = ROOT.TLegend(0.28, 0.28, 0.68, 0.48) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_eec_0mb, "0mb", "PE")
legend.AddEntry(tgraph_eec_3mb, "3.0mb", "PE")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_inclusive_log_plot_markers.pdf")
canvas.Close()

# %% [markdown]
# ## ratios

# %%
# log version of ratio, with markers

ROOT.gDirectory.Clear()

eec_0mb , eec_3mb = initialise(filepath_0mb_inc, filepath_3mb_inc)

#rebin
rebinned_eec_0mb = rebin_log(eec_0mb, "eec_0mb_log", 50)
rebinned_eec_3mb = rebin_log(eec_3mb, "eec_3mb_log", 50)

# 3. Create a clone of the rebinned 3mb histogram to hold the ratio
rebinned_ratio_eecs = rebinned_eec_3mb.Clone("rebinned_ratio_log")

# 4. Divide the rebinned histograms (This computes the correct ratio!)
# DO NOT call .Scale(1.0, "width") on this ratio.
rebinned_ratio_eecs.Divide(rebinned_eec_0mb)

# make TGraphErrors
tgraph_ratio = ROOT.TGraphErrors(rebinned_ratio_eecs)

# Choosing colours:
tgraph_ratio.SetLineColorAlpha(colours[0], 0.7)

tgraph_ratio.SetMarkerColorAlpha(colours[0], 0.7)

# markers:
tgraph_ratio.SetMarkerStyle(20)

tgraph_ratio.SetMarkerSize(0.8)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l_r", "rebinned log ratio of EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_ratio, "PE")

# title
mg.SetTitle("Ratio of EECs for inclusive datasets (rebinned); #Delta R_{L}; E2C_{3.0mb} / E2C_{0mb}")
mg.Draw("A") 

# reference line
line = ROOT.TLine(0, 1.0, 1.0, 1.0)
line.SetLineStyle(2) # Dashed configuration
line.SetLineColor(ROOT.kBlack)
line.Draw()

# scale axes
canvas.SetLogx(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0, 2)
mg.SetMinimum(0.98)
mg.SetMaximum(1.02)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)


# Legend setup
legend = ROOT.TLegend(0.28, 0.78, 0.48, 0.88) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_ratio, "Ratio of EECs", "PE")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_rebinned_inclusive_ratio_log_markers.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_rebinned_inclusive_ratio_log_markers.pdf has been created

# %%
# log version of ratio, with markers, rebinned in the nonlog way

ROOT.gDirectory.Clear()

eec_0mb , eec_3mb = initialise(filepath_0mb_inc, filepath_3mb_inc)

#rebin
rebinned_eec_0mb , rebinned_eec_3mb = rebin_nonlog(eec_0mb, eec_3mb, "rebinned_eec_0mb", "rebinned_eec_3mb", 10)

# get ratio
rebinned_ratio_eecs = rebinned_eec_3mb.Clone("ratio_nonlog")
rebinned_ratio_eecs.Divide(rebinned_eec_0mb)

# make TGraphErrors
tgraph_ratio = ROOT.TGraphErrors(rebinned_ratio_eecs)

# Choosing colours:
tgraph_ratio.SetLineColorAlpha(colours[0], 0.7)

tgraph_ratio.SetMarkerColorAlpha(colours[0], 0.7)

# markers:
tgraph_ratio.SetMarkerStyle(20)

tgraph_ratio.SetMarkerSize(0.8)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l_r", "rebinned log ratio of EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_ratio, "PE")

# title
mg.SetTitle("Ratio of EECs for inclusive datasets (rebinned); #Delta R_{L}; E2C_{3.0mb} / E2C_{0mb}")
mg.Draw("A") 

# reference line
line = ROOT.TLine(0, 1.0, 1.0, 1.0)
line.SetLineStyle(2) # Dashed configuration
line.SetLineColor(ROOT.kBlack)
line.Draw()

# scale axes
canvas.SetLogx(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0, 2)
mg.SetMinimum(0.98)
mg.SetMaximum(1.02)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)


# Legend setup
legend = ROOT.TLegend(0.28, 0.78, 0.48, 0.88) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_ratio, "Ratio of EECs", "PE")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_rebinned_nl_inclusive_ratio_log_markers.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_rebinned_nl_inclusive_ratio_log_markers.pdf has been created

# %%
# non log version of ratio, with markers, rebinned

ROOT.gDirectory.Clear()

eec_0mb , eec_3mb = initialise(filepath_0mb_inc, filepath_3mb_inc)

#rebin
rebinned_eec_0mb , rebinned_eec_3mb = rebin_nonlog(eec_0mb, eec_3mb, "rebinned_eec_0mb", "rebinned_eec_3mb", 10)

# get ratio
rebinned_ratio_eecs = rebinned_eec_3mb.Clone("ratio_nonlog")
rebinned_ratio_eecs.Divide(rebinned_eec_0mb)

# make TGraphErrors
tgraph_ratio = ROOT.TGraphErrors(rebinned_ratio_eecs)

# Choosing colours:
tgraph_ratio.SetLineColorAlpha(colours[0], 0.7)

tgraph_ratio.SetMarkerColorAlpha(colours[0], 0.7)

# markers:
tgraph_ratio.SetMarkerStyle(20)

tgraph_ratio.SetMarkerSize(0.8)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l_r", "ratio of EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_ratio, "PE")

# title
mg.SetTitle("Ratio of EECs for inclusive datasets; #Delta R_{L}; E2C_{3.0mb} / E2C_{0mb}")
mg.Draw("A") 

# reference line
line = ROOT.TLine(0, 1.0, 1.0, 1.0)
line.SetLineStyle(2) # Dashed configuration
line.SetLineColor(ROOT.kBlack)
line.Draw()

# scale axes
mg.GetXaxis().SetLimits(0, 1.0)
mg.GetYaxis().SetLimits(0, 2)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)


# Legend setup
legend = ROOT.TLegend(0.28, 0.78, 0.48, 0.88) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_ratio, "Ratio of EECs", "PE")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_rebinned_inclusive_ratio_nonlog_markers.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_rebinned_inclusive_ratio_nonlog_markers.pdf has been created

# %%
# log version of ratio, without markers

ROOT.gDirectory.Clear()

eec_0mb , eec_3mb = initialise(filepath_0mb_inc, filepath_3mb_inc)

#rebin
rebinned_eec_0mb = rebin_log(eec_0mb, "eec_0mb_log", 50)
rebinned_eec_3mb = rebin_log(eec_3mb, "eec_3mb_log", 50)

# 3. Create a clone of the rebinned 3mb histogram to hold the ratio
rebinned_ratio_eecs = rebinned_eec_3mb.Clone("rebinned_ratio_log")

# 4. Divide the rebinned histograms (This computes the correct ratio!)
# DO NOT call .Scale(1.0, "width") on this ratio.
rebinned_ratio_eecs.Divide(rebinned_eec_0mb)

# make TGraphErrors
tgraph_ratio = ROOT.TGraphErrors(rebinned_ratio_eecs)

# Choosing colours:
tgraph_ratio.SetLineColorAlpha(colours[0], 0.7)

tgraph_ratio.SetMarkerColorAlpha(colours[0], 0.7)

# markers:
tgraph_ratio.SetMarkerStyle(20)

tgraph_ratio.SetMarkerSize(0.8)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l_r", "rebinned log ratio of EECs for inclusive datasets", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_ratio, "LX")

# title
mg.SetTitle("Ratio of EECs for inclusive datasets (rebinned); #Delta R_{L}; E2C_{3.0mb} / E2C_{0mb}")
mg.Draw("A") 

# reference line
line = ROOT.TLine(0, 1.0, 1.0, 1.0)
line.SetLineStyle(2) # Dashed configuration
line.SetLineColor(ROOT.kBlack)
line.Draw()

# scale axes
canvas.SetLogx(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0, 2)
mg.SetMinimum(0.98)
mg.SetMaximum(1.02)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)


# Legend setup
legend = ROOT.TLegend(0.28, 0.78, 0.48, 0.88) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_ratio, "Ratio of EECs", "PE")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_rebinned_inclusive_ratio_log_smooth.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_rebinned_inclusive_ratio_log_smooth.pdf has been created
