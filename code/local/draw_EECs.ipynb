# %% [markdown]
# draws the Energy profiles and EECs.

# %%
import ROOT
import numpy as np
import matplotlib.pyplot as plt
import os
import ctypes

# %%
high_bins = [ [60,71], [71,78], [78,91], [91,97], [97,1000] ]
inclusive_bins = [ [0,25], [25,36], [36,48], [48,60]  ]
analysis_bins = [ [0,25], [25,36], [36,48], [48,60], [60,71], [71,78], [78,91], [91,97], [97,1000] ]

# %%
filepath_3mb_nch60 = "/Users/rohanjagadeesan/Desktop/Code/li_lab/EnergyCorrelators/output/3mb_nch60/Merged_EECs.root"
filepath_0mb_nch60 = "/Users/rohanjagadeesan/Desktop/Code/li_lab/EnergyCorrelators/output/0mb_nch60/Merged_EECs.root"
filepath_3mb_izpc = "/Users/rohanjagadeesan/Desktop/Code/li_lab/EnergyCorrelators/output/3mb_izpc/Merged_EECs.root"

# %%
ROOT.gDirectory.Clear()
def initialise(filepath):
    tfile = ROOT.TFile.Open(filepath, "READ")

    wta_profiles = {}
    std_profiles = {}
    EECs = {} # using standard

    for mult_bin in high_bins:
        bin_key = f"{mult_bin[0]} < Nch < {mult_bin[1]}"
        bin_name = f"{mult_bin[0]}_{mult_bin[1]}"

        wta_profiles[bin_key] = ROOT.TGraphErrors( tfile.Get(f"WTA_profile_{bin_name}").Clone() )
        std_profiles[bin_key] = ROOT.TGraphErrors( tfile.Get(f"STD_profile_{bin_name}").Clone() )
        EECs[bin_key] = ROOT.TGraphErrors( tfile.Get(f"STD_eec_{bin_name}").Clone() )

        # detach them
        #wta_profiles[bin_key].SetDirectory(0)
        #std_profiles[bin_key].SetDirectory(0)
        #EECs[bin_key].SetDirectory(0)
    
    return wta_profiles, std_profiles, EECs

# %%
colours = [ROOT.kBlue+1, ROOT.kMagenta+1, ROOT.kSpring+4, ROOT.kRed+1, ROOT.kOrange+7]

# %% [markdown]
# # EEC plots:

# %% [markdown]
# ### 3mb nch60

# %%
# with error bars
ROOT.gDirectory.Clear()
wta_profiles, std_profiles, EECs = initialise(filepath_3mb_nch60)

# pick out the TGraphErrors
eec_60_71 = EECs["60 < Nch < 71"]
eec_71_78 = EECs["71 < Nch < 78"]
eec_78_91 = EECs["78 < Nch < 91"]
eec_91_97 = EECs["91 < Nch < 97"]
eec_97_1000 = EECs["97 < Nch < 1000"]

# Choosing colours:
eec_60_71.SetLineColorAlpha(colours[0], 0.7)
eec_71_78.SetLineColorAlpha(colours[1], 0.7)
eec_78_91.SetLineColorAlpha(colours[2], 0.7)
eec_91_97.SetLineColorAlpha(colours[3], 0.7)
eec_97_1000.SetLineColorAlpha(colours[4], 0.7)

eec_60_71.SetMarkerColorAlpha(colours[0], 0.7)
eec_71_78.SetMarkerColorAlpha(colours[1], 0.7)
eec_78_91.SetMarkerColorAlpha(colours[2], 0.7)
eec_91_97.SetMarkerColorAlpha(colours[3], 0.7)
eec_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

# if you want markers:
eec_60_71.SetMarkerSize(0.4)
eec_71_78.SetMarkerSize(0.4)
eec_78_91.SetMarkerSize(0.4)
eec_91_97.SetMarkerSize(0.4)
eec_97_1000.SetMarkerSize(0.4)

# if you don't want markers:
eec_60_71.SetMarkerStyle(1)
eec_71_78.SetMarkerStyle(1)
eec_78_91.SetMarkerStyle(1)
eec_91_97.SetMarkerStyle(1)
eec_97_1000.SetMarkerStyle(1)
#eec_60_71.SetMarkerSize(0)
#eec_71_78.SetMarkerSize(0)
#eec_78_91.SetMarkerSize(0)
#eec_91_97.SetMarkerSize(0)
#eec_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_eec", "EECs for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(eec_60_71, "L")
mg.Add(eec_71_78, "L")
mg.Add(eec_78_91, "L")
mg.Add(eec_91_97, "L")
mg.Add(eec_97_1000, "L")

# no error bars version:
#mg.Add(eec_60_71, "LX")
#mg.Add(eec_71_78, "LX")
#mg.Add(eec_78_91, "LX")
#mg.Add(eec_91_97, "LX")
#mg.Add(eec_97_1000, "LX")

# title
mg.SetTitle("EEC for high multiplicity bins; #Delta R_{L}; E2C")
mg.Draw("A") 

# Log scale axes
#canvas.SetLogx(1)
#canvas.SetLogy(1)
#mg.GetXaxis().SetLimits(0.001, 1.0)
#mg.GetYaxis().SetLimits(0.0001, 1.0)

# non log version:
mg.GetXaxis().SetLimits(0, 1.0)
mg.GetYaxis().SetLimits(0, 1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

# Legend setup
legend = ROOT.TLegend(0.48, 0.68, 0.88, 0.88)
#legend = ROOT.TLegend(0.28, 0.28, 0.68, 0.48) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(eec_60_71, "60 #leq N_{ch} < 71", "L")
legend.AddEntry(eec_71_78, "71 #leq N_{ch} < 78", "L")
legend.AddEntry(eec_78_91, "78 #leq N_{ch} < 91", "L")
legend.AddEntry(eec_91_97, "91 #leq N_{ch} < 97", "L")
legend.AddEntry(eec_97_1000, "97 #leq N_{ch} < 1000", "L")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_plot.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_plot.pdf has been created

# %%
# log version, no markers

ROOT.gDirectory.Clear()

# pick out the TGraphErrors
eec_60_71 = EECs["60 < Nch < 71"]
eec_71_78 = EECs["71 < Nch < 78"]
eec_78_91 = EECs["78 < Nch < 91"]
eec_91_97 = EECs["91 < Nch < 97"]
eec_97_1000 = EECs["97 < Nch < 1000"]

# Choosing colours:
eec_60_71.SetLineColorAlpha(colours[0], 0.7)
eec_71_78.SetLineColorAlpha(colours[1], 0.7)
eec_78_91.SetLineColorAlpha(colours[2], 0.7)
eec_91_97.SetLineColorAlpha(colours[3], 0.7)
eec_97_1000.SetLineColorAlpha(colours[4], 0.7)

eec_60_71.SetMarkerColorAlpha(colours[0], 0.7)
eec_71_78.SetMarkerColorAlpha(colours[1], 0.7)
eec_78_91.SetMarkerColorAlpha(colours[2], 0.7)
eec_91_97.SetMarkerColorAlpha(colours[3], 0.7)
eec_97_1000.SetMarkerColorAlpha(colours[4], 0.7)


# if you don't want markers:
eec_60_71.SetMarkerStyle(1)
eec_71_78.SetMarkerStyle(1)
eec_78_91.SetMarkerStyle(1)
eec_91_97.SetMarkerStyle(1)
eec_97_1000.SetMarkerStyle(1)
eec_60_71.SetMarkerSize(0)
eec_71_78.SetMarkerSize(0)
eec_78_91.SetMarkerSize(0)
eec_91_97.SetMarkerSize(0)
eec_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l", "log EECs for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
# no error bars version:
mg.Add(eec_60_71, "LX")
mg.Add(eec_71_78, "LX")
mg.Add(eec_78_91, "LX")
mg.Add(eec_91_97, "LX")
mg.Add(eec_97_1000, "LX")

# title
mg.SetTitle("EEC for high multiplicity bins; #Delta R_{L}; E2C")
mg.Draw("A") 

# Log scale axes
canvas.SetLogx(1)
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

# Legend setup
legend = ROOT.TLegend(0.28, 0.28, 0.68, 0.48) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(eec_60_71, "60 #leq N_{ch} < 71", "L")
legend.AddEntry(eec_71_78, "71 #leq N_{ch} < 78", "L")
legend.AddEntry(eec_78_91, "78 #leq N_{ch} < 91", "L")
legend.AddEntry(eec_91_97, "91 #leq N_{ch} < 97", "L")
legend.AddEntry(eec_97_1000, "97 #leq N_{ch} < 1000", "L")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_log_plot.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_log_plot.pdf has been created

# %%
# log version, WITH markers

ROOT.gDirectory.Clear()
wta_profiles, std_profiles, EECs = initialise(filepath_3mb_nch60)


# pick out the TGraphErrors
eec_60_71 = EECs["60 < Nch < 71"]
eec_71_78 = EECs["71 < Nch < 78"]
eec_78_91 = EECs["78 < Nch < 91"]
eec_91_97 = EECs["91 < Nch < 97"]
eec_97_1000 = EECs["97 < Nch < 1000"]

# Choosing colours:
eec_60_71.SetLineColorAlpha(colours[0], 0.7)
eec_71_78.SetLineColorAlpha(colours[1], 0.7)
eec_78_91.SetLineColorAlpha(colours[2], 0.7)
eec_91_97.SetLineColorAlpha(colours[3], 0.7)
eec_97_1000.SetLineColorAlpha(colours[4], 0.7)

eec_60_71.SetMarkerColorAlpha(colours[0], 0.7)
eec_71_78.SetMarkerColorAlpha(colours[1], 0.7)
eec_78_91.SetMarkerColorAlpha(colours[2], 0.7)
eec_91_97.SetMarkerColorAlpha(colours[3], 0.7)
eec_97_1000.SetMarkerColorAlpha(colours[4], 0.7)


# if you don't want markers:
eec_60_71.SetMarkerStyle(1)
eec_71_78.SetMarkerStyle(1)
eec_78_91.SetMarkerStyle(1)
eec_91_97.SetMarkerStyle(1)
eec_97_1000.SetMarkerStyle(1)
eec_60_71.SetMarkerSize(0.4)
eec_71_78.SetMarkerSize(0.4)
eec_78_91.SetMarkerSize(0.4)
eec_91_97.SetMarkerSize(0.4)
eec_97_1000.SetMarkerSize(0.4)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l", "log EECs for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
# no error bars version:
mg.Add(eec_60_71, "PE")
mg.Add(eec_71_78, "PE")
mg.Add(eec_78_91, "PE")
mg.Add(eec_91_97, "PE")
mg.Add(eec_97_1000, "PE")

# title
mg.SetTitle("EEC for high multiplicity bins; #Delta R_{L}; E2C")
mg.Draw("A") 

# Log scale axes
canvas.SetLogx(1)
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

# Legend setup
legend = ROOT.TLegend(0.28, 0.28, 0.68, 0.48) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(eec_60_71, "60 #leq N_{ch} < 71", "L")
legend.AddEntry(eec_71_78, "71 #leq N_{ch} < 78", "L")
legend.AddEntry(eec_78_91, "78 #leq N_{ch} < 91", "L")
legend.AddEntry(eec_91_97, "91 #leq N_{ch} < 97", "L")
legend.AddEntry(eec_97_1000, "97 #leq N_{ch} < 1000", "L")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_log_plot_pe_3mb.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_log_plot_pe_3mb.pdf has been created

# %%
# log version, no markers, EXTRA X AXIS
ROOT.gDirectory.Clear()
# pick out the TGraphErrors
eec_60_71 = EECs["60 < Nch < 71"]
eec_71_78 = EECs["71 < Nch < 78"]
eec_78_91 = EECs["78 < Nch < 91"]
eec_91_97 = EECs["91 < Nch < 97"]
eec_97_1000 = EECs["97 < Nch < 1000"]

# Choosing colours:
eec_60_71.SetLineColorAlpha(colours[0], 0.7)
eec_71_78.SetLineColorAlpha(colours[1], 0.7)
eec_78_91.SetLineColorAlpha(colours[2], 0.7)
eec_91_97.SetLineColorAlpha(colours[3], 0.7)
eec_97_1000.SetLineColorAlpha(colours[4], 0.7)

eec_60_71.SetMarkerColorAlpha(colours[0], 0.7)
eec_71_78.SetMarkerColorAlpha(colours[1], 0.7)
eec_78_91.SetMarkerColorAlpha(colours[2], 0.7)
eec_91_97.SetMarkerColorAlpha(colours[3], 0.7)
eec_97_1000.SetMarkerColorAlpha(colours[4], 0.7)


# if you don't want markers:
eec_60_71.SetMarkerStyle(1)
eec_71_78.SetMarkerStyle(1)
eec_78_91.SetMarkerStyle(1)
eec_91_97.SetMarkerStyle(1)
eec_97_1000.SetMarkerStyle(1)
eec_60_71.SetMarkerSize(0)
eec_71_78.SetMarkerSize(0)
eec_78_91.SetMarkerSize(0)
eec_91_97.SetMarkerSize(0)
eec_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l", "log EECs for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
# no error bars version:
mg.Add(eec_60_71, "LX")
mg.Add(eec_71_78, "LX")
mg.Add(eec_78_91, "LX")
mg.Add(eec_91_97, "LX")
mg.Add(eec_97_1000, "LX")

# title
mg.SetTitle("EEC for high multiplicity bins; #Delta R_{L}; E2C")
mg.Draw("A") 

# Log scale axes
canvas.SetLogx(1)
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0.001, 10)
mg.GetYaxis().SetLimits(0.0001, 1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

# Legend setup
legend = ROOT.TLegend(0.28, 0.28, 0.68, 0.48) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(eec_60_71, "60 #leq N_{ch} < 71", "L")
legend.AddEntry(eec_71_78, "71 #leq N_{ch} < 78", "L")
legend.AddEntry(eec_78_91, "78 #leq N_{ch} < 91", "L")
legend.AddEntry(eec_91_97, "91 #leq N_{ch} < 97", "L")
legend.AddEntry(eec_97_1000, "97 #leq N_{ch} < 1000", "L")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_log_extra_plot.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_log_extra_plot.pdf has been created

# %% [markdown]
# ### 3mb izpc

# %%
# log version, no markers

ROOT.gDirectory.Clear()

wta_profiles, std_profiles, EECs = initialise(filepath_3mb_izpc)

# pick out the TGraphErrors
eec_60_71 = EECs["60 < Nch < 71"]
eec_71_78 = EECs["71 < Nch < 78"]
eec_78_91 = EECs["78 < Nch < 91"]
eec_91_97 = EECs["91 < Nch < 97"]
eec_97_1000 = EECs["97 < Nch < 1000"]

# Choosing colours:
eec_60_71.SetLineColorAlpha(colours[0], 0.7)
eec_71_78.SetLineColorAlpha(colours[1], 0.7)
eec_78_91.SetLineColorAlpha(colours[2], 0.7)
eec_91_97.SetLineColorAlpha(colours[3], 0.7)
eec_97_1000.SetLineColorAlpha(colours[4], 0.7)

eec_60_71.SetMarkerColorAlpha(colours[0], 0.7)
eec_71_78.SetMarkerColorAlpha(colours[1], 0.7)
eec_78_91.SetMarkerColorAlpha(colours[2], 0.7)
eec_91_97.SetMarkerColorAlpha(colours[3], 0.7)
eec_97_1000.SetMarkerColorAlpha(colours[4], 0.7)


# if you don't want markers:
eec_60_71.SetMarkerStyle(1)
eec_71_78.SetMarkerStyle(1)
eec_78_91.SetMarkerStyle(1)
eec_91_97.SetMarkerStyle(1)
eec_97_1000.SetMarkerStyle(1)
eec_60_71.SetMarkerSize(0)
eec_71_78.SetMarkerSize(0)
eec_78_91.SetMarkerSize(0)
eec_91_97.SetMarkerSize(0)
eec_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l", "log EECs for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
# no error bars version:
mg.Add(eec_60_71, "LX")
mg.Add(eec_71_78, "LX")
mg.Add(eec_78_91, "LX")
mg.Add(eec_91_97, "LX")
mg.Add(eec_97_1000, "LX")

# title
mg.SetTitle("EEC for high multiplicity bins; #Delta R_{L}; E2C")
mg.Draw("A") 

# Log scale axes
canvas.SetLogx(1)
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

# Legend setup
legend = ROOT.TLegend(0.28, 0.28, 0.68, 0.48) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(eec_60_71, "60 #leq N_{ch} < 71", "L")
legend.AddEntry(eec_71_78, "71 #leq N_{ch} < 78", "L")
legend.AddEntry(eec_78_91, "78 #leq N_{ch} < 91", "L")
legend.AddEntry(eec_91_97, "91 #leq N_{ch} < 97", "L")
legend.AddEntry(eec_97_1000, "97 #leq N_{ch} < 1000", "L")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_log_plot.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_log_plot.pdf has been created

# %% [markdown]
# ### 0mb nch60

# %%
# log version, no markers

ROOT.gDirectory.Clear()

wta_profiles, std_profiles, EECs = initialise(filepath_0mb_nch60)

# pick out the TGraphErrors
eec_60_71 = EECs["60 < Nch < 71"]
eec_71_78 = EECs["71 < Nch < 78"]
eec_78_91 = EECs["78 < Nch < 91"]
eec_91_97 = EECs["91 < Nch < 97"]
eec_97_1000 = EECs["97 < Nch < 1000"]

# Choosing colours:
eec_60_71.SetLineColorAlpha(colours[0], 0.7)
eec_71_78.SetLineColorAlpha(colours[1], 0.7)
eec_78_91.SetLineColorAlpha(colours[2], 0.7)
eec_91_97.SetLineColorAlpha(colours[3], 0.7)
eec_97_1000.SetLineColorAlpha(colours[4], 0.7)

eec_60_71.SetMarkerColorAlpha(colours[0], 0.7)
eec_71_78.SetMarkerColorAlpha(colours[1], 0.7)
eec_78_91.SetMarkerColorAlpha(colours[2], 0.7)
eec_91_97.SetMarkerColorAlpha(colours[3], 0.7)
eec_97_1000.SetMarkerColorAlpha(colours[4], 0.7)


# if you don't want markers:
eec_60_71.SetMarkerStyle(1)
eec_71_78.SetMarkerStyle(1)
eec_78_91.SetMarkerStyle(1)
eec_91_97.SetMarkerStyle(1)
eec_97_1000.SetMarkerStyle(1)
eec_60_71.SetMarkerSize(0)
eec_71_78.SetMarkerSize(0)
eec_78_91.SetMarkerSize(0)
eec_91_97.SetMarkerSize(0)
eec_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_l", "log EECs for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
# no error bars version:
mg.Add(eec_60_71, "LX")
mg.Add(eec_71_78, "LX")
mg.Add(eec_78_91, "LX")
mg.Add(eec_91_97, "LX")
mg.Add(eec_97_1000, "LX")

# title
mg.SetTitle("EEC for high multiplicity bins (0mb); #Delta R_{L}; E2C")
mg.Draw("A") 

# Log scale axes
canvas.SetLogx(1)
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

# Legend setup
legend = ROOT.TLegend(0.28, 0.28, 0.68, 0.48) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(eec_60_71, "60 #leq N_{ch} < 71", "L")
legend.AddEntry(eec_71_78, "71 #leq N_{ch} < 78", "L")
legend.AddEntry(eec_78_91, "78 #leq N_{ch} < 91", "L")
legend.AddEntry(eec_91_97, "91 #leq N_{ch} < 97", "L")
legend.AddEntry(eec_97_1000, "97 #leq N_{ch} < 1000", "L")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_log_plot_0mb.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_log_plot_0mb.pdf has been created

# %% [markdown]
# ### combined 3mb nch60 and 0mb nch60

# %% [markdown]
# # profile plots:

# %% [markdown]
# ### 3mb nch60

# %%
# log version of profiles, no markers
ROOT.gDirectory.Clear()
wta_profiles, std_profiles, EECs = initialise(filepath_3mb_nch60)

# pick out the TGraphErrors
wta_60_71 = wta_profiles["60 < Nch < 71"]
wta_71_78 = wta_profiles["71 < Nch < 78"]
wta_78_91 = wta_profiles["78 < Nch < 91"]
wta_91_97 = wta_profiles["91 < Nch < 97"]
wta_97_1000 = wta_profiles["97 < Nch < 1000"]

std_60_71 = std_profiles["60 < Nch < 71"]
std_71_78 = std_profiles["71 < Nch < 78"]
std_78_91 = std_profiles["78 < Nch < 91"]
std_91_97 = std_profiles["91 < Nch < 97"]
std_97_1000 = std_profiles["97 < Nch < 1000"]

# Choosing colours:
wta_60_71.SetLineColorAlpha(colours[0], 0.7)
wta_71_78.SetLineColorAlpha(colours[1], 0.7)
wta_78_91.SetLineColorAlpha(colours[2], 0.7)
wta_91_97.SetLineColorAlpha(colours[3], 0.7)
wta_97_1000.SetLineColorAlpha(colours[4], 0.7)

std_60_71.SetLineColorAlpha(colours[0], 0.7)
std_71_78.SetLineColorAlpha(colours[1], 0.7)
std_78_91.SetLineColorAlpha(colours[2], 0.7)
std_91_97.SetLineColorAlpha(colours[3], 0.7)
std_97_1000.SetLineColorAlpha(colours[4], 0.7)

wta_60_71.SetMarkerColorAlpha(colours[0], 0.7)
wta_71_78.SetMarkerColorAlpha(colours[1], 0.7)
wta_78_91.SetMarkerColorAlpha(colours[2], 0.7)
wta_91_97.SetMarkerColorAlpha(colours[3], 0.7)
wta_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

std_60_71.SetMarkerColorAlpha(colours[0], 0.7)
std_71_78.SetMarkerColorAlpha(colours[1], 0.7)
std_78_91.SetMarkerColorAlpha(colours[2], 0.7)
std_91_97.SetMarkerColorAlpha(colours[3], 0.7)
std_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

# line styles
wta_60_71.SetLineStyle(3)
wta_71_78.SetLineStyle(3)
wta_78_91.SetLineStyle(3)
wta_91_97.SetLineStyle(3)
wta_97_1000.SetLineStyle(3)

std_60_71.SetLineStyle(4)
std_71_78.SetLineStyle(4)
std_78_91.SetLineStyle(4)
std_91_97.SetLineStyle(4)
std_97_1000.SetLineStyle(4)

# if you don't want markers:
wta_60_71.SetMarkerStyle(1)
wta_71_78.SetMarkerStyle(1)
wta_78_91.SetMarkerStyle(1)
wta_91_97.SetMarkerStyle(1)
wta_97_1000.SetMarkerStyle(1)
wta_60_71.SetMarkerSize(0)
wta_71_78.SetMarkerSize(0)
wta_78_91.SetMarkerSize(0)
wta_91_97.SetMarkerSize(0)
wta_97_1000.SetMarkerSize(0)

std_60_71.SetMarkerStyle(1)
std_71_78.SetMarkerStyle(1)
std_78_91.SetMarkerStyle(1)
std_91_97.SetMarkerStyle(1)
std_97_1000.SetMarkerStyle(1)
std_60_71.SetMarkerSize(0)
std_71_78.SetMarkerSize(0)
std_78_91.SetMarkerSize(0)
std_91_97.SetMarkerSize(0)
std_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_profile_l", "log profiles for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
# no error bars version:
mg.Add(wta_60_71, "LX")
mg.Add(wta_71_78, "LX")
mg.Add(wta_78_91, "LX")
mg.Add(wta_91_97, "LX")
mg.Add(wta_97_1000, "LX")

mg.Add(std_60_71, "LX")
mg.Add(std_71_78, "LX")
mg.Add(std_78_91, "LX")
mg.Add(std_91_97, "LX")
mg.Add(std_97_1000, "LX")

# smooth lines:
mg.Add(wta_60_71, "CX")
mg.Add(wta_71_78, "CX")
mg.Add(wta_78_91, "CX")
mg.Add(wta_91_97, "CX")
mg.Add(wta_97_1000, "CX")


# title
mg.SetTitle("Energy profiles for high multiplicity bins; #Delta R_{L}; Profile")

# Log scale axes
canvas.SetLogx(1)
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)
mg.SetMaximum(1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

mg.Draw("A") 

# Legend setup
legend1 = ROOT.TLegend(0.18, 0.68, 0.28, 0.88) 
legend1.SetBorderSize(0)
legend1.SetFillStyle(0) 
legend1.SetTextSize(0.035)

legend1.AddEntry(std_60_71, "STD 60 #leq N_{ch} < 71", "L")
legend1.AddEntry(std_71_78, "STD 71 #leq N_{ch} < 78", "L")
legend1.AddEntry(std_78_91, "STD 78 #leq N_{ch} < 91", "L")
legend1.AddEntry(std_91_97, "STD 91 #leq N_{ch} < 97", "L")
legend1.AddEntry(std_97_1000, "STD 97 #leq N_{ch} < 1000", "L")
legend1.Draw()

legend2 = ROOT.TLegend(0.48, 0.68, 0.68, 0.88) 
legend2.SetBorderSize(0)
legend2.SetFillStyle(0) 
legend2.SetTextSize(0.035)

legend2.AddEntry(wta_60_71, "WTA 60 #leq N_{ch} < 71", "L")
legend2.AddEntry(wta_71_78, "WTA 71 #leq N_{ch} < 78", "L")
legend2.AddEntry(wta_78_91, "WTA 78 #leq N_{ch} < 91", "L")
legend2.AddEntry(wta_91_97, "WTA 91 #leq N_{ch} < 97", "L")
legend2.AddEntry(wta_97_1000, "WTA 97 #leq N_{ch} < 1000", "L")
legend2.Draw()


canvas.Update()
canvas.SaveAs("Energy_profile_plot.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file Energy_profile_plot.pdf has been created

# %%
# log version of profiles, no markers, smooth lines
ROOT.gDirectory.Clear()
wta_profiles, std_profiles, EECs = initialise(filepath_3mb_nch60)

# pick out the TGraphErrors
wta_60_71 = wta_profiles["60 < Nch < 71"]
wta_71_78 = wta_profiles["71 < Nch < 78"]
wta_78_91 = wta_profiles["78 < Nch < 91"]
wta_91_97 = wta_profiles["91 < Nch < 97"]
wta_97_1000 = wta_profiles["97 < Nch < 1000"]

std_60_71 = std_profiles["60 < Nch < 71"]
std_71_78 = std_profiles["71 < Nch < 78"]
std_78_91 = std_profiles["78 < Nch < 91"]
std_91_97 = std_profiles["91 < Nch < 97"]
std_97_1000 = std_profiles["97 < Nch < 1000"]

# Choosing colours:
wta_60_71.SetLineColorAlpha(colours[0], 0.7)
wta_71_78.SetLineColorAlpha(colours[1], 0.7)
wta_78_91.SetLineColorAlpha(colours[2], 0.7)
wta_91_97.SetLineColorAlpha(colours[3], 0.7)
wta_97_1000.SetLineColorAlpha(colours[4], 0.7)

std_60_71.SetLineColorAlpha(colours[0], 0.7)
std_71_78.SetLineColorAlpha(colours[1], 0.7)
std_78_91.SetLineColorAlpha(colours[2], 0.7)
std_91_97.SetLineColorAlpha(colours[3], 0.7)
std_97_1000.SetLineColorAlpha(colours[4], 0.7)

wta_60_71.SetMarkerColorAlpha(colours[0], 0.7)
wta_71_78.SetMarkerColorAlpha(colours[1], 0.7)
wta_78_91.SetMarkerColorAlpha(colours[2], 0.7)
wta_91_97.SetMarkerColorAlpha(colours[3], 0.7)
wta_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

std_60_71.SetMarkerColorAlpha(colours[0], 0.7)
std_71_78.SetMarkerColorAlpha(colours[1], 0.7)
std_78_91.SetMarkerColorAlpha(colours[2], 0.7)
std_91_97.SetMarkerColorAlpha(colours[3], 0.7)
std_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

# line styles
wta_60_71.SetLineStyle(1)
wta_71_78.SetLineStyle(1)
wta_78_91.SetLineStyle(1)
wta_91_97.SetLineStyle(1)
wta_97_1000.SetLineStyle(1)

std_60_71.SetLineStyle(3)
std_71_78.SetLineStyle(3)
std_78_91.SetLineStyle(3)
std_91_97.SetLineStyle(3)
std_97_1000.SetLineStyle(3)

# line width
wta_60_71.SetLineWidth(1)
wta_71_78.SetLineWidth(1)
wta_78_91.SetLineWidth(1)
wta_91_97.SetLineWidth(1)
wta_97_1000.SetLineWidth(1)

std_60_71.SetLineWidth(2)
std_71_78.SetLineWidth(2)
std_78_91.SetLineWidth(2)
std_91_97.SetLineWidth(2)
std_97_1000.SetLineWidth(2)

# if you don't want markers:
wta_60_71.SetMarkerStyle(4)
wta_71_78.SetMarkerStyle(4)
wta_78_91.SetMarkerStyle(4)
wta_91_97.SetMarkerStyle(4)
wta_97_1000.SetMarkerStyle(4)
#wta_60_71.SetMarkerSize(0)
#wta_71_78.SetMarkerSize(0)
#wta_78_91.SetMarkerSize(0)
#wta_91_97.SetMarkerSize(0)
#wta_97_1000.SetMarkerSize(0)

std_60_71.SetMarkerStyle(21)
std_71_78.SetMarkerStyle(21)
std_78_91.SetMarkerStyle(21)
std_91_97.SetMarkerStyle(21)
std_97_1000.SetMarkerStyle(21)
#std_60_71.SetMarkerSize(0)
#std_71_78.SetMarkerSize(0)
#std_78_91.SetMarkerSize(0)
#std_91_97.SetMarkerSize(0)
#std_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_profile_l", "log profiles for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
# no error bars version:
# smooth lines:
mg.Add(wta_60_71, "CX")
mg.Add(wta_71_78, "CX")
mg.Add(wta_78_91, "CX")
mg.Add(wta_91_97, "CX")
mg.Add(wta_97_1000, "CX")

mg.Add(std_60_71, "CX")
mg.Add(std_71_78, "CX")
mg.Add(std_78_91, "CX")
mg.Add(std_91_97, "CX")
mg.Add(std_97_1000, "CX")

# title
mg.SetTitle("Energy profiles for high multiplicity bins; #Delta R_{L}; Profile")

# Log scale axes
canvas.SetLogx(1)
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)
mg.SetMaximum(1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

mg.Draw("A") 

# Legend setup
legend1 = ROOT.TLegend(0.18, 0.70, 0.28, 0.88) 
legend1.SetBorderSize(0)
legend1.SetFillStyle(0) 
legend1.SetTextSize(0.035)

legend1.AddEntry(std_60_71, "STD 60 #leq N_{ch} < 71", "L")
legend1.AddEntry(std_71_78, "STD 71 #leq N_{ch} < 78", "L")
legend1.AddEntry(std_78_91, "STD 78 #leq N_{ch} < 91", "L")
legend1.AddEntry(std_91_97, "STD 91 #leq N_{ch} < 97", "L")
legend1.AddEntry(std_97_1000, "STD 97 #leq N_{ch} < 1000", "L")
legend1.Draw()

legend2 = ROOT.TLegend(0.48, 0.70, 0.68, 0.88) 
legend2.SetBorderSize(0)
legend2.SetFillStyle(0) 
legend2.SetTextSize(0.035)

legend2.AddEntry(wta_60_71, "WTA 60 #leq N_{ch} < 71", "L")
legend2.AddEntry(wta_71_78, "WTA 71 #leq N_{ch} < 78", "L")
legend2.AddEntry(wta_78_91, "WTA 78 #leq N_{ch} < 91", "L")
legend2.AddEntry(wta_91_97, "WTA 91 #leq N_{ch} < 97", "L")
legend2.AddEntry(wta_97_1000, "WTA 97 #leq N_{ch} < 1000", "L")
legend2.Draw()


canvas.Update()
canvas.SaveAs("Energy_profile_plot_smooth.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file Energy_profile_plot_smooth.pdf has been created

# %%
# non-log version of profiles, no markers, smooth lines
ROOT.gDirectory.Clear()
wta_profiles, std_profiles, EECs = initialise(filepath_3mb_nch60)

# pick out the TGraphErrors
wta_60_71 = wta_profiles["60 < Nch < 71"]
wta_71_78 = wta_profiles["71 < Nch < 78"]
wta_78_91 = wta_profiles["78 < Nch < 91"]
wta_91_97 = wta_profiles["91 < Nch < 97"]
wta_97_1000 = wta_profiles["97 < Nch < 1000"]

std_60_71 = std_profiles["60 < Nch < 71"]
std_71_78 = std_profiles["71 < Nch < 78"]
std_78_91 = std_profiles["78 < Nch < 91"]
std_91_97 = std_profiles["91 < Nch < 97"]
std_97_1000 = std_profiles["97 < Nch < 1000"]

# Choosing colours:
wta_60_71.SetLineColorAlpha(colours[0], 0.7)
wta_71_78.SetLineColorAlpha(colours[1], 0.7)
wta_78_91.SetLineColorAlpha(colours[2], 0.7)
wta_91_97.SetLineColorAlpha(colours[3], 0.7)
wta_97_1000.SetLineColorAlpha(colours[4], 0.7)

std_60_71.SetLineColorAlpha(colours[0], 0.7)
std_71_78.SetLineColorAlpha(colours[1], 0.7)
std_78_91.SetLineColorAlpha(colours[2], 0.7)
std_91_97.SetLineColorAlpha(colours[3], 0.7)
std_97_1000.SetLineColorAlpha(colours[4], 0.7)

wta_60_71.SetMarkerColorAlpha(colours[0], 0.7)
wta_71_78.SetMarkerColorAlpha(colours[1], 0.7)
wta_78_91.SetMarkerColorAlpha(colours[2], 0.7)
wta_91_97.SetMarkerColorAlpha(colours[3], 0.7)
wta_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

std_60_71.SetMarkerColorAlpha(colours[0], 0.7)
std_71_78.SetMarkerColorAlpha(colours[1], 0.7)
std_78_91.SetMarkerColorAlpha(colours[2], 0.7)
std_91_97.SetMarkerColorAlpha(colours[3], 0.7)
std_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

# line styles
wta_60_71.SetLineStyle(1)
wta_71_78.SetLineStyle(1)
wta_78_91.SetLineStyle(1)
wta_91_97.SetLineStyle(1)
wta_97_1000.SetLineStyle(1)

std_60_71.SetLineStyle(3)
std_71_78.SetLineStyle(3)
std_78_91.SetLineStyle(3)
std_91_97.SetLineStyle(3)
std_97_1000.SetLineStyle(3)

# line width
wta_60_71.SetLineWidth(1)
wta_71_78.SetLineWidth(1)
wta_78_91.SetLineWidth(1)
wta_91_97.SetLineWidth(1)
wta_97_1000.SetLineWidth(1)

std_60_71.SetLineWidth(2)
std_71_78.SetLineWidth(2)
std_78_91.SetLineWidth(2)
std_91_97.SetLineWidth(2)
std_97_1000.SetLineWidth(2)

# if you don't want markers:
wta_60_71.SetMarkerStyle(4)
wta_71_78.SetMarkerStyle(4)
wta_78_91.SetMarkerStyle(4)
wta_91_97.SetMarkerStyle(4)
wta_97_1000.SetMarkerStyle(4)
#wta_60_71.SetMarkerSize(0)
#wta_71_78.SetMarkerSize(0)
#wta_78_91.SetMarkerSize(0)
#wta_91_97.SetMarkerSize(0)
#wta_97_1000.SetMarkerSize(0)

std_60_71.SetMarkerStyle(21)
std_71_78.SetMarkerStyle(21)
std_78_91.SetMarkerStyle(21)
std_91_97.SetMarkerStyle(21)
std_97_1000.SetMarkerStyle(21)
#std_60_71.SetMarkerSize(0)
#std_71_78.SetMarkerSize(0)
#std_78_91.SetMarkerSize(0)
#std_91_97.SetMarkerSize(0)
#std_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_profile_l", "log profiles for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
# no error bars version:
# smooth lines:
mg.Add(wta_60_71, "CX")
mg.Add(wta_71_78, "CX")
mg.Add(wta_78_91, "CX")
mg.Add(wta_91_97, "CX")
mg.Add(wta_97_1000, "CX")

mg.Add(std_60_71, "CX")
mg.Add(std_71_78, "CX")
mg.Add(std_78_91, "CX")
mg.Add(std_91_97, "CX")
mg.Add(std_97_1000, "CX")

# title
mg.SetTitle("Energy profiles for high multiplicity bins; #Delta R_{L}; Profile")

# Log scale axes
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)
mg.SetMaximum(1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

mg.Draw("A") 

# Legend setup
legend1 = ROOT.TLegend(0.18, 0.70, 0.28, 0.88) 
legend1.SetBorderSize(0)
legend1.SetFillStyle(0) 
legend1.SetTextSize(0.035)

legend1.AddEntry(std_60_71, "STD 60 #leq N_{ch} < 71", "L")
legend1.AddEntry(std_71_78, "STD 71 #leq N_{ch} < 78", "L")
legend1.AddEntry(std_78_91, "STD 78 #leq N_{ch} < 91", "L")
legend1.AddEntry(std_91_97, "STD 91 #leq N_{ch} < 97", "L")
legend1.AddEntry(std_97_1000, "STD 97 #leq N_{ch} < 1000", "L")
legend1.Draw()

legend2 = ROOT.TLegend(0.48, 0.70, 0.68, 0.88) 
legend2.SetBorderSize(0)
legend2.SetFillStyle(0) 
legend2.SetTextSize(0.035)

legend2.AddEntry(wta_60_71, "WTA 60 #leq N_{ch} < 71", "L")
legend2.AddEntry(wta_71_78, "WTA 71 #leq N_{ch} < 78", "L")
legend2.AddEntry(wta_78_91, "WTA 78 #leq N_{ch} < 91", "L")
legend2.AddEntry(wta_91_97, "WTA 91 #leq N_{ch} < 97", "L")
legend2.AddEntry(wta_97_1000, "WTA 97 #leq N_{ch} < 1000", "L")
legend2.Draw()


canvas.Update()
canvas.SaveAs("Energy_profile_plot_nonlog_x.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file Energy_profile_plot_nonlog.pdf has been created

# %%
# non-log on both x and y version of profiles, no markers, smooth lines
ROOT.gDirectory.Clear()
wta_profiles, std_profiles, EECs = initialise(filepath_3mb_nch60)

# pick out the TGraphErrors
wta_60_71 = wta_profiles["60 < Nch < 71"]
wta_71_78 = wta_profiles["71 < Nch < 78"]
wta_78_91 = wta_profiles["78 < Nch < 91"]
wta_91_97 = wta_profiles["91 < Nch < 97"]
wta_97_1000 = wta_profiles["97 < Nch < 1000"]

std_60_71 = std_profiles["60 < Nch < 71"]
std_71_78 = std_profiles["71 < Nch < 78"]
std_78_91 = std_profiles["78 < Nch < 91"]
std_91_97 = std_profiles["91 < Nch < 97"]
std_97_1000 = std_profiles["97 < Nch < 1000"]

# Choosing colours:
wta_60_71.SetLineColorAlpha(colours[0], 0.7)
wta_71_78.SetLineColorAlpha(colours[1], 0.7)
wta_78_91.SetLineColorAlpha(colours[2], 0.7)
wta_91_97.SetLineColorAlpha(colours[3], 0.7)
wta_97_1000.SetLineColorAlpha(colours[4], 0.7)

std_60_71.SetLineColorAlpha(colours[0], 0.7)
std_71_78.SetLineColorAlpha(colours[1], 0.7)
std_78_91.SetLineColorAlpha(colours[2], 0.7)
std_91_97.SetLineColorAlpha(colours[3], 0.7)
std_97_1000.SetLineColorAlpha(colours[4], 0.7)

wta_60_71.SetMarkerColorAlpha(colours[0], 0.7)
wta_71_78.SetMarkerColorAlpha(colours[1], 0.7)
wta_78_91.SetMarkerColorAlpha(colours[2], 0.7)
wta_91_97.SetMarkerColorAlpha(colours[3], 0.7)
wta_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

std_60_71.SetMarkerColorAlpha(colours[0], 0.7)
std_71_78.SetMarkerColorAlpha(colours[1], 0.7)
std_78_91.SetMarkerColorAlpha(colours[2], 0.7)
std_91_97.SetMarkerColorAlpha(colours[3], 0.7)
std_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

# line styles
wta_60_71.SetLineStyle(1)
wta_71_78.SetLineStyle(1)
wta_78_91.SetLineStyle(1)
wta_91_97.SetLineStyle(1)
wta_97_1000.SetLineStyle(1)

std_60_71.SetLineStyle(3)
std_71_78.SetLineStyle(3)
std_78_91.SetLineStyle(3)
std_91_97.SetLineStyle(3)
std_97_1000.SetLineStyle(3)

# line width
wta_60_71.SetLineWidth(1)
wta_71_78.SetLineWidth(1)
wta_78_91.SetLineWidth(1)
wta_91_97.SetLineWidth(1)
wta_97_1000.SetLineWidth(1)

std_60_71.SetLineWidth(2)
std_71_78.SetLineWidth(2)
std_78_91.SetLineWidth(2)
std_91_97.SetLineWidth(2)
std_97_1000.SetLineWidth(2)

# if you don't want markers:
wta_60_71.SetMarkerStyle(4)
wta_71_78.SetMarkerStyle(4)
wta_78_91.SetMarkerStyle(4)
wta_91_97.SetMarkerStyle(4)
wta_97_1000.SetMarkerStyle(4)
#wta_60_71.SetMarkerSize(0)
#wta_71_78.SetMarkerSize(0)
#wta_78_91.SetMarkerSize(0)
#wta_91_97.SetMarkerSize(0)
#wta_97_1000.SetMarkerSize(0)

std_60_71.SetMarkerStyle(21)
std_71_78.SetMarkerStyle(21)
std_78_91.SetMarkerStyle(21)
std_91_97.SetMarkerStyle(21)
std_97_1000.SetMarkerStyle(21)
#std_60_71.SetMarkerSize(0)
#std_71_78.SetMarkerSize(0)
#std_78_91.SetMarkerSize(0)
#std_91_97.SetMarkerSize(0)
#std_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_profile_l", "log profiles for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
# no error bars version:
# smooth lines:
mg.Add(wta_60_71, "CX")
mg.Add(wta_71_78, "CX")
mg.Add(wta_78_91, "CX")
mg.Add(wta_91_97, "CX")
mg.Add(wta_97_1000, "CX")

mg.Add(std_60_71, "CX")
mg.Add(std_71_78, "CX")
mg.Add(std_78_91, "CX")
mg.Add(std_91_97, "CX")
mg.Add(std_97_1000, "CX")

# title
mg.SetTitle("Energy profiles for high multiplicity bins; #Delta R_{L}; Profile")

# Log scale axes
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)
mg.SetMaximum(0.012)
mg.SetMinimum(0.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

mg.Draw("A") 

# Legend setup
legend1 = ROOT.TLegend(0.18, 0.70, 0.28, 0.88) 
legend1.SetBorderSize(0)
legend1.SetFillStyle(0) 
legend1.SetTextSize(0.035)

legend1.AddEntry(std_60_71, "STD 60 #leq N_{ch} < 71", "L")
legend1.AddEntry(std_71_78, "STD 71 #leq N_{ch} < 78", "L")
legend1.AddEntry(std_78_91, "STD 78 #leq N_{ch} < 91", "L")
legend1.AddEntry(std_91_97, "STD 91 #leq N_{ch} < 97", "L")
legend1.AddEntry(std_97_1000, "STD 97 #leq N_{ch} < 1000", "L")
legend1.Draw()

legend2 = ROOT.TLegend(0.48, 0.70, 0.68, 0.88) 
legend2.SetBorderSize(0)
legend2.SetFillStyle(0) 
legend2.SetTextSize(0.035)

legend2.AddEntry(wta_60_71, "WTA 60 #leq N_{ch} < 71", "L")
legend2.AddEntry(wta_71_78, "WTA 71 #leq N_{ch} < 78", "L")
legend2.AddEntry(wta_78_91, "WTA 78 #leq N_{ch} < 91", "L")
legend2.AddEntry(wta_91_97, "WTA 91 #leq N_{ch} < 97", "L")
legend2.AddEntry(wta_97_1000, "WTA 97 #leq N_{ch} < 1000", "L")
legend2.Draw()


canvas.Update()
canvas.SaveAs("Energy_profile_plot_nonlog.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file Energy_profile_plot_nonlog.pdf has been created

# %% [markdown]
# ### 3mb izpc

# %%
# log version of profiles, no markers, smooth lines
ROOT.gDirectory.Clear()
wta_profiles, std_profiles, EECs = initialise(filepath_3mb_izpc)

# pick out the TGraphErrors
wta_60_71 = wta_profiles["60 < Nch < 71"]
wta_71_78 = wta_profiles["71 < Nch < 78"]
wta_78_91 = wta_profiles["78 < Nch < 91"]
wta_91_97 = wta_profiles["91 < Nch < 97"]
wta_97_1000 = wta_profiles["97 < Nch < 1000"]

std_60_71 = std_profiles["60 < Nch < 71"]
std_71_78 = std_profiles["71 < Nch < 78"]
std_78_91 = std_profiles["78 < Nch < 91"]
std_91_97 = std_profiles["91 < Nch < 97"]
std_97_1000 = std_profiles["97 < Nch < 1000"]

# Choosing colours:
wta_60_71.SetLineColorAlpha(colours[0], 0.7)
wta_71_78.SetLineColorAlpha(colours[1], 0.7)
wta_78_91.SetLineColorAlpha(colours[2], 0.7)
wta_91_97.SetLineColorAlpha(colours[3], 0.7)
wta_97_1000.SetLineColorAlpha(colours[4], 0.7)

std_60_71.SetLineColorAlpha(colours[0], 0.7)
std_71_78.SetLineColorAlpha(colours[1], 0.7)
std_78_91.SetLineColorAlpha(colours[2], 0.7)
std_91_97.SetLineColorAlpha(colours[3], 0.7)
std_97_1000.SetLineColorAlpha(colours[4], 0.7)

wta_60_71.SetMarkerColorAlpha(colours[0], 0.7)
wta_71_78.SetMarkerColorAlpha(colours[1], 0.7)
wta_78_91.SetMarkerColorAlpha(colours[2], 0.7)
wta_91_97.SetMarkerColorAlpha(colours[3], 0.7)
wta_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

std_60_71.SetMarkerColorAlpha(colours[0], 0.7)
std_71_78.SetMarkerColorAlpha(colours[1], 0.7)
std_78_91.SetMarkerColorAlpha(colours[2], 0.7)
std_91_97.SetMarkerColorAlpha(colours[3], 0.7)
std_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

# line styles
wta_60_71.SetLineStyle(1)
wta_71_78.SetLineStyle(1)
wta_78_91.SetLineStyle(1)
wta_91_97.SetLineStyle(1)
wta_97_1000.SetLineStyle(1)

std_60_71.SetLineStyle(3)
std_71_78.SetLineStyle(3)
std_78_91.SetLineStyle(3)
std_91_97.SetLineStyle(3)
std_97_1000.SetLineStyle(3)

# line width
wta_60_71.SetLineWidth(1)
wta_71_78.SetLineWidth(1)
wta_78_91.SetLineWidth(1)
wta_91_97.SetLineWidth(1)
wta_97_1000.SetLineWidth(1)

std_60_71.SetLineWidth(2)
std_71_78.SetLineWidth(2)
std_78_91.SetLineWidth(2)
std_91_97.SetLineWidth(2)
std_97_1000.SetLineWidth(2)

# if you don't want markers:
wta_60_71.SetMarkerStyle(4)
wta_71_78.SetMarkerStyle(4)
wta_78_91.SetMarkerStyle(4)
wta_91_97.SetMarkerStyle(4)
wta_97_1000.SetMarkerStyle(4)
#wta_60_71.SetMarkerSize(0)
#wta_71_78.SetMarkerSize(0)
#wta_78_91.SetMarkerSize(0)
#wta_91_97.SetMarkerSize(0)
#wta_97_1000.SetMarkerSize(0)

std_60_71.SetMarkerStyle(21)
std_71_78.SetMarkerStyle(21)
std_78_91.SetMarkerStyle(21)
std_91_97.SetMarkerStyle(21)
std_97_1000.SetMarkerStyle(21)
#std_60_71.SetMarkerSize(0)
#std_71_78.SetMarkerSize(0)
#std_78_91.SetMarkerSize(0)
#std_91_97.SetMarkerSize(0)
#std_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_profile_l", "log profiles for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
# no error bars version:
# smooth lines:
mg.Add(wta_60_71, "CX")
mg.Add(wta_71_78, "CX")
mg.Add(wta_78_91, "CX")
mg.Add(wta_91_97, "CX")
mg.Add(wta_97_1000, "CX")

mg.Add(std_60_71, "CX")
mg.Add(std_71_78, "CX")
mg.Add(std_78_91, "CX")
mg.Add(std_91_97, "CX")
mg.Add(std_97_1000, "CX")

# title
mg.SetTitle("Energy profiles for high multiplicity bins; #Delta R_{L}; Profile")

# Log scale axes
canvas.SetLogx(1)
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)
mg.SetMaximum(1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

mg.Draw("A") 

# Legend setup
legend1 = ROOT.TLegend(0.18, 0.70, 0.28, 0.88) 
legend1.SetBorderSize(0)
legend1.SetFillStyle(0) 
legend1.SetTextSize(0.035)

legend1.AddEntry(std_60_71, "STD 60 #leq N_{ch} < 71", "L")
legend1.AddEntry(std_71_78, "STD 71 #leq N_{ch} < 78", "L")
legend1.AddEntry(std_78_91, "STD 78 #leq N_{ch} < 91", "L")
legend1.AddEntry(std_91_97, "STD 91 #leq N_{ch} < 97", "L")
legend1.AddEntry(std_97_1000, "STD 97 #leq N_{ch} < 1000", "L")
legend1.Draw()

legend2 = ROOT.TLegend(0.48, 0.70, 0.68, 0.88) 
legend2.SetBorderSize(0)
legend2.SetFillStyle(0) 
legend2.SetTextSize(0.035)

legend2.AddEntry(wta_60_71, "WTA 60 #leq N_{ch} < 71", "L")
legend2.AddEntry(wta_71_78, "WTA 71 #leq N_{ch} < 78", "L")
legend2.AddEntry(wta_78_91, "WTA 78 #leq N_{ch} < 91", "L")
legend2.AddEntry(wta_91_97, "WTA 91 #leq N_{ch} < 97", "L")
legend2.AddEntry(wta_97_1000, "WTA 97 #leq N_{ch} < 1000", "L")
legend2.Draw()


canvas.Update()
canvas.SaveAs("Energy_profile_plot_smooth.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file Energy_profile_plot_smooth.pdf has been created

# %%
# non-log on both x and y version of profiles, no markers, smooth lines
ROOT.gDirectory.Clear()
wta_profiles, std_profiles, EECs = initialise(filepath_3mb_izpc)

# pick out the TGraphErrors
wta_60_71 = wta_profiles["60 < Nch < 71"]
wta_71_78 = wta_profiles["71 < Nch < 78"]
wta_78_91 = wta_profiles["78 < Nch < 91"]
wta_91_97 = wta_profiles["91 < Nch < 97"]
wta_97_1000 = wta_profiles["97 < Nch < 1000"]

std_60_71 = std_profiles["60 < Nch < 71"]
std_71_78 = std_profiles["71 < Nch < 78"]
std_78_91 = std_profiles["78 < Nch < 91"]
std_91_97 = std_profiles["91 < Nch < 97"]
std_97_1000 = std_profiles["97 < Nch < 1000"]

# Choosing colours:
wta_60_71.SetLineColorAlpha(colours[0], 0.7)
wta_71_78.SetLineColorAlpha(colours[1], 0.7)
wta_78_91.SetLineColorAlpha(colours[2], 0.7)
wta_91_97.SetLineColorAlpha(colours[3], 0.7)
wta_97_1000.SetLineColorAlpha(colours[4], 0.7)

std_60_71.SetLineColorAlpha(colours[0], 0.7)
std_71_78.SetLineColorAlpha(colours[1], 0.7)
std_78_91.SetLineColorAlpha(colours[2], 0.7)
std_91_97.SetLineColorAlpha(colours[3], 0.7)
std_97_1000.SetLineColorAlpha(colours[4], 0.7)

wta_60_71.SetMarkerColorAlpha(colours[0], 0.7)
wta_71_78.SetMarkerColorAlpha(colours[1], 0.7)
wta_78_91.SetMarkerColorAlpha(colours[2], 0.7)
wta_91_97.SetMarkerColorAlpha(colours[3], 0.7)
wta_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

std_60_71.SetMarkerColorAlpha(colours[0], 0.7)
std_71_78.SetMarkerColorAlpha(colours[1], 0.7)
std_78_91.SetMarkerColorAlpha(colours[2], 0.7)
std_91_97.SetMarkerColorAlpha(colours[3], 0.7)
std_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

# line styles
wta_60_71.SetLineStyle(1)
wta_71_78.SetLineStyle(1)
wta_78_91.SetLineStyle(1)
wta_91_97.SetLineStyle(1)
wta_97_1000.SetLineStyle(1)

std_60_71.SetLineStyle(3)
std_71_78.SetLineStyle(3)
std_78_91.SetLineStyle(3)
std_91_97.SetLineStyle(3)
std_97_1000.SetLineStyle(3)

# line width
wta_60_71.SetLineWidth(1)
wta_71_78.SetLineWidth(1)
wta_78_91.SetLineWidth(1)
wta_91_97.SetLineWidth(1)
wta_97_1000.SetLineWidth(1)

std_60_71.SetLineWidth(2)
std_71_78.SetLineWidth(2)
std_78_91.SetLineWidth(2)
std_91_97.SetLineWidth(2)
std_97_1000.SetLineWidth(2)

# if you don't want markers:
wta_60_71.SetMarkerStyle(4)
wta_71_78.SetMarkerStyle(4)
wta_78_91.SetMarkerStyle(4)
wta_91_97.SetMarkerStyle(4)
wta_97_1000.SetMarkerStyle(4)
#wta_60_71.SetMarkerSize(0)
#wta_71_78.SetMarkerSize(0)
#wta_78_91.SetMarkerSize(0)
#wta_91_97.SetMarkerSize(0)
#wta_97_1000.SetMarkerSize(0)

std_60_71.SetMarkerStyle(21)
std_71_78.SetMarkerStyle(21)
std_78_91.SetMarkerStyle(21)
std_91_97.SetMarkerStyle(21)
std_97_1000.SetMarkerStyle(21)
#std_60_71.SetMarkerSize(0)
#std_71_78.SetMarkerSize(0)
#std_78_91.SetMarkerSize(0)
#std_91_97.SetMarkerSize(0)
#std_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_profile_l", "log profiles for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
# no error bars version:
# smooth lines:
mg.Add(wta_60_71, "CX")
mg.Add(wta_71_78, "CX")
mg.Add(wta_78_91, "CX")
mg.Add(wta_91_97, "CX")
mg.Add(wta_97_1000, "CX")

mg.Add(std_60_71, "CX")
mg.Add(std_71_78, "CX")
mg.Add(std_78_91, "CX")
mg.Add(std_91_97, "CX")
mg.Add(std_97_1000, "CX")

# title
mg.SetTitle("Energy profiles for high multiplicity bins; #Delta R_{L}; Profile")

# Log scale axes
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)
mg.SetMaximum(0.012)
mg.SetMinimum(0.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

mg.Draw("A") 

# Legend setup
legend1 = ROOT.TLegend(0.18, 0.70, 0.28, 0.88) 
legend1.SetBorderSize(0)
legend1.SetFillStyle(0) 
legend1.SetTextSize(0.035)

legend1.AddEntry(std_60_71, "STD 60 #leq N_{ch} < 71", "L")
legend1.AddEntry(std_71_78, "STD 71 #leq N_{ch} < 78", "L")
legend1.AddEntry(std_78_91, "STD 78 #leq N_{ch} < 91", "L")
legend1.AddEntry(std_91_97, "STD 91 #leq N_{ch} < 97", "L")
legend1.AddEntry(std_97_1000, "STD 97 #leq N_{ch} < 1000", "L")
legend1.Draw()

legend2 = ROOT.TLegend(0.48, 0.70, 0.68, 0.88) 
legend2.SetBorderSize(0)
legend2.SetFillStyle(0) 
legend2.SetTextSize(0.035)

legend2.AddEntry(wta_60_71, "WTA 60 #leq N_{ch} < 71", "L")
legend2.AddEntry(wta_71_78, "WTA 71 #leq N_{ch} < 78", "L")
legend2.AddEntry(wta_78_91, "WTA 78 #leq N_{ch} < 91", "L")
legend2.AddEntry(wta_91_97, "WTA 91 #leq N_{ch} < 97", "L")
legend2.AddEntry(wta_97_1000, "WTA 97 #leq N_{ch} < 1000", "L")
legend2.Draw()


canvas.Update()
canvas.SaveAs("Energy_profile_plot_nonlog.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file Energy_profile_plot_nonlog.pdf has been created

# %% [markdown]
# ### 0mb nch60

# %%
# log version of profiles, no markers, smooth lines
ROOT.gDirectory.Clear()
wta_profiles, std_profiles, EECs = initialise(filepath_0mb_nch60)

# pick out the TGraphErrors
wta_60_71 = wta_profiles["60 < Nch < 71"]
wta_71_78 = wta_profiles["71 < Nch < 78"]
wta_78_91 = wta_profiles["78 < Nch < 91"]
wta_91_97 = wta_profiles["91 < Nch < 97"]
wta_97_1000 = wta_profiles["97 < Nch < 1000"]

std_60_71 = std_profiles["60 < Nch < 71"]
std_71_78 = std_profiles["71 < Nch < 78"]
std_78_91 = std_profiles["78 < Nch < 91"]
std_91_97 = std_profiles["91 < Nch < 97"]
std_97_1000 = std_profiles["97 < Nch < 1000"]

# Choosing colours:
wta_60_71.SetLineColorAlpha(colours[0], 0.7)
wta_71_78.SetLineColorAlpha(colours[1], 0.7)
wta_78_91.SetLineColorAlpha(colours[2], 0.7)
wta_91_97.SetLineColorAlpha(colours[3], 0.7)
wta_97_1000.SetLineColorAlpha(colours[4], 0.7)

std_60_71.SetLineColorAlpha(colours[0], 0.7)
std_71_78.SetLineColorAlpha(colours[1], 0.7)
std_78_91.SetLineColorAlpha(colours[2], 0.7)
std_91_97.SetLineColorAlpha(colours[3], 0.7)
std_97_1000.SetLineColorAlpha(colours[4], 0.7)

wta_60_71.SetMarkerColorAlpha(colours[0], 0.7)
wta_71_78.SetMarkerColorAlpha(colours[1], 0.7)
wta_78_91.SetMarkerColorAlpha(colours[2], 0.7)
wta_91_97.SetMarkerColorAlpha(colours[3], 0.7)
wta_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

std_60_71.SetMarkerColorAlpha(colours[0], 0.7)
std_71_78.SetMarkerColorAlpha(colours[1], 0.7)
std_78_91.SetMarkerColorAlpha(colours[2], 0.7)
std_91_97.SetMarkerColorAlpha(colours[3], 0.7)
std_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

# line styles
wta_60_71.SetLineStyle(1)
wta_71_78.SetLineStyle(1)
wta_78_91.SetLineStyle(1)
wta_91_97.SetLineStyle(1)
wta_97_1000.SetLineStyle(1)

std_60_71.SetLineStyle(3)
std_71_78.SetLineStyle(3)
std_78_91.SetLineStyle(3)
std_91_97.SetLineStyle(3)
std_97_1000.SetLineStyle(3)

# line width
wta_60_71.SetLineWidth(1)
wta_71_78.SetLineWidth(1)
wta_78_91.SetLineWidth(1)
wta_91_97.SetLineWidth(1)
wta_97_1000.SetLineWidth(1)

std_60_71.SetLineWidth(2)
std_71_78.SetLineWidth(2)
std_78_91.SetLineWidth(2)
std_91_97.SetLineWidth(2)
std_97_1000.SetLineWidth(2)

# if you don't want markers:
wta_60_71.SetMarkerStyle(4)
wta_71_78.SetMarkerStyle(4)
wta_78_91.SetMarkerStyle(4)
wta_91_97.SetMarkerStyle(4)
wta_97_1000.SetMarkerStyle(4)
#wta_60_71.SetMarkerSize(0)
#wta_71_78.SetMarkerSize(0)
#wta_78_91.SetMarkerSize(0)
#wta_91_97.SetMarkerSize(0)
#wta_97_1000.SetMarkerSize(0)

std_60_71.SetMarkerStyle(21)
std_71_78.SetMarkerStyle(21)
std_78_91.SetMarkerStyle(21)
std_91_97.SetMarkerStyle(21)
std_97_1000.SetMarkerStyle(21)
#std_60_71.SetMarkerSize(0)
#std_71_78.SetMarkerSize(0)
#std_78_91.SetMarkerSize(0)
#std_91_97.SetMarkerSize(0)
#std_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_profile_l", "log profiles for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
# no error bars version:
# smooth lines:
mg.Add(wta_60_71, "CX")
mg.Add(wta_71_78, "CX")
mg.Add(wta_78_91, "CX")
mg.Add(wta_91_97, "CX")
mg.Add(wta_97_1000, "CX")

mg.Add(std_60_71, "CX")
mg.Add(std_71_78, "CX")
mg.Add(std_78_91, "CX")
mg.Add(std_91_97, "CX")
mg.Add(std_97_1000, "CX")

# title
mg.SetTitle("Energy profiles for high multiplicity bins (0mb); #Delta R_{L}; Profile")

# Log scale axes
canvas.SetLogx(1)
canvas.SetLogy(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)
mg.SetMaximum(1.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

mg.Draw("A") 

# Legend setup
legend1 = ROOT.TLegend(0.18, 0.70, 0.28, 0.88) 
legend1.SetBorderSize(0)
legend1.SetFillStyle(0) 
legend1.SetTextSize(0.035)

legend1.AddEntry(std_60_71, "STD 60 #leq N_{ch} < 71", "L")
legend1.AddEntry(std_71_78, "STD 71 #leq N_{ch} < 78", "L")
legend1.AddEntry(std_78_91, "STD 78 #leq N_{ch} < 91", "L")
legend1.AddEntry(std_91_97, "STD 91 #leq N_{ch} < 97", "L")
legend1.AddEntry(std_97_1000, "STD 97 #leq N_{ch} < 1000", "L")
legend1.Draw()

legend2 = ROOT.TLegend(0.48, 0.70, 0.68, 0.88) 
legend2.SetBorderSize(0)
legend2.SetFillStyle(0) 
legend2.SetTextSize(0.035)

legend2.AddEntry(wta_60_71, "WTA 60 #leq N_{ch} < 71", "L")
legend2.AddEntry(wta_71_78, "WTA 71 #leq N_{ch} < 78", "L")
legend2.AddEntry(wta_78_91, "WTA 78 #leq N_{ch} < 91", "L")
legend2.AddEntry(wta_91_97, "WTA 91 #leq N_{ch} < 97", "L")
legend2.AddEntry(wta_97_1000, "WTA 97 #leq N_{ch} < 1000", "L")
legend2.Draw()


canvas.Update()
canvas.SaveAs("Energy_profile_plot_smooth_0mb.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file Energy_profile_plot_smooth_0mb.pdf has been created

# %%
# non-log on both x and y version of profiles, no markers, smooth lines
ROOT.gDirectory.Clear()
wta_profiles, std_profiles, EECs = initialise(filepath_0mb_nch60)

# pick out the TGraphErrors
wta_60_71 = wta_profiles["60 < Nch < 71"]
wta_71_78 = wta_profiles["71 < Nch < 78"]
wta_78_91 = wta_profiles["78 < Nch < 91"]
wta_91_97 = wta_profiles["91 < Nch < 97"]
wta_97_1000 = wta_profiles["97 < Nch < 1000"]

std_60_71 = std_profiles["60 < Nch < 71"]
std_71_78 = std_profiles["71 < Nch < 78"]
std_78_91 = std_profiles["78 < Nch < 91"]
std_91_97 = std_profiles["91 < Nch < 97"]
std_97_1000 = std_profiles["97 < Nch < 1000"]

# Choosing colours:
wta_60_71.SetLineColorAlpha(colours[0], 0.7)
wta_71_78.SetLineColorAlpha(colours[1], 0.7)
wta_78_91.SetLineColorAlpha(colours[2], 0.7)
wta_91_97.SetLineColorAlpha(colours[3], 0.7)
wta_97_1000.SetLineColorAlpha(colours[4], 0.7)

std_60_71.SetLineColorAlpha(colours[0], 0.7)
std_71_78.SetLineColorAlpha(colours[1], 0.7)
std_78_91.SetLineColorAlpha(colours[2], 0.7)
std_91_97.SetLineColorAlpha(colours[3], 0.7)
std_97_1000.SetLineColorAlpha(colours[4], 0.7)

wta_60_71.SetMarkerColorAlpha(colours[0], 0.7)
wta_71_78.SetMarkerColorAlpha(colours[1], 0.7)
wta_78_91.SetMarkerColorAlpha(colours[2], 0.7)
wta_91_97.SetMarkerColorAlpha(colours[3], 0.7)
wta_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

std_60_71.SetMarkerColorAlpha(colours[0], 0.7)
std_71_78.SetMarkerColorAlpha(colours[1], 0.7)
std_78_91.SetMarkerColorAlpha(colours[2], 0.7)
std_91_97.SetMarkerColorAlpha(colours[3], 0.7)
std_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

# line styles
wta_60_71.SetLineStyle(1)
wta_71_78.SetLineStyle(1)
wta_78_91.SetLineStyle(1)
wta_91_97.SetLineStyle(1)
wta_97_1000.SetLineStyle(1)

std_60_71.SetLineStyle(3)
std_71_78.SetLineStyle(3)
std_78_91.SetLineStyle(3)
std_91_97.SetLineStyle(3)
std_97_1000.SetLineStyle(3)

# line width
wta_60_71.SetLineWidth(1)
wta_71_78.SetLineWidth(1)
wta_78_91.SetLineWidth(1)
wta_91_97.SetLineWidth(1)
wta_97_1000.SetLineWidth(1)

std_60_71.SetLineWidth(2)
std_71_78.SetLineWidth(2)
std_78_91.SetLineWidth(2)
std_91_97.SetLineWidth(2)
std_97_1000.SetLineWidth(2)

# if you don't want markers:
wta_60_71.SetMarkerStyle(4)
wta_71_78.SetMarkerStyle(4)
wta_78_91.SetMarkerStyle(4)
wta_91_97.SetMarkerStyle(4)
wta_97_1000.SetMarkerStyle(4)
#wta_60_71.SetMarkerSize(0)
#wta_71_78.SetMarkerSize(0)
#wta_78_91.SetMarkerSize(0)
#wta_91_97.SetMarkerSize(0)
#wta_97_1000.SetMarkerSize(0)

std_60_71.SetMarkerStyle(21)
std_71_78.SetMarkerStyle(21)
std_78_91.SetMarkerStyle(21)
std_91_97.SetMarkerStyle(21)
std_97_1000.SetMarkerStyle(21)
#std_60_71.SetMarkerSize(0)
#std_71_78.SetMarkerSize(0)
#std_78_91.SetMarkerSize(0)
#std_91_97.SetMarkerSize(0)
#std_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_profile_l", "log profiles for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
# no error bars version:
# smooth lines:
mg.Add(wta_60_71, "CX")
mg.Add(wta_71_78, "CX")
mg.Add(wta_78_91, "CX")
mg.Add(wta_91_97, "CX")
mg.Add(wta_97_1000, "CX")

mg.Add(std_60_71, "CX")
mg.Add(std_71_78, "CX")
mg.Add(std_78_91, "CX")
mg.Add(std_91_97, "CX")
mg.Add(std_97_1000, "CX")

# title
mg.SetTitle("Energy profiles for high multiplicity bins (0mb); #Delta R_{L}; Profile")

# Log scale axes
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0.0001, 1.0)
mg.SetMaximum(0.012)
mg.SetMinimum(0.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)

mg.Draw("A") 

# Legend setup
legend1 = ROOT.TLegend(0.18, 0.70, 0.28, 0.88) 
legend1.SetBorderSize(0)
legend1.SetFillStyle(0) 
legend1.SetTextSize(0.035)

legend1.AddEntry(std_60_71, "STD 60 #leq N_{ch} < 71", "L")
legend1.AddEntry(std_71_78, "STD 71 #leq N_{ch} < 78", "L")
legend1.AddEntry(std_78_91, "STD 78 #leq N_{ch} < 91", "L")
legend1.AddEntry(std_91_97, "STD 91 #leq N_{ch} < 97", "L")
legend1.AddEntry(std_97_1000, "STD 97 #leq N_{ch} < 1000", "L")
legend1.Draw()

legend2 = ROOT.TLegend(0.48, 0.70, 0.68, 0.88) 
legend2.SetBorderSize(0)
legend2.SetFillStyle(0) 
legend2.SetTextSize(0.035)

legend2.AddEntry(wta_60_71, "WTA 60 #leq N_{ch} < 71", "L")
legend2.AddEntry(wta_71_78, "WTA 71 #leq N_{ch} < 78", "L")
legend2.AddEntry(wta_78_91, "WTA 78 #leq N_{ch} < 91", "L")
legend2.AddEntry(wta_91_97, "WTA 91 #leq N_{ch} < 97", "L")
legend2.AddEntry(wta_97_1000, "WTA 97 #leq N_{ch} < 1000", "L")
legend2.Draw()


canvas.Update()
canvas.SaveAs("Energy_profile_plot_nonlog_0mb.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file Energy_profile_plot_nonlog_0mb.pdf has been created

# %% [markdown]
# # Ratios

# %%
# new initialising function - forget about profiles
ROOT.gDirectory.Clear()
def ratio_initialise(filepath1, filepath2):
    
    tfile1 = ROOT.TFile.Open(filepath1, "READ")
    EECs1 = {} # using standard
    for mult_bin in high_bins:
        bin_key = f"{mult_bin[0]} < Nch < {mult_bin[1]}"
        bin_name = f"{mult_bin[0]}_{mult_bin[1]}"

        #EECs1[bin_key] = ROOT.TGraphErrors( tfile1.Get(f"STD_eec_{bin_name}").Clone() )
        EECs1[bin_key] = tfile1.Get(f"STD_eec_{bin_name}").Clone()
        EECs1[bin_key].SetDirectory(0)

    tfile1.Close()

    tfile2 = ROOT.TFile.Open(filepath2, "READ")
    EECs2 = {}
    for mult_bin in high_bins:
        bin_key = f"{mult_bin[0]} < Nch < {mult_bin[1]}"
        bin_name = f"{mult_bin[0]}_{mult_bin[1]}"
        #EECs2[bin_key] = ROOT.TGraphErrors( tfile2.Get(f"STD_eec_{bin_name}").Clone() )
        EECs2[bin_key] = tfile2.Get(f"STD_eec_{bin_name}").Clone()
        EECs2[bin_key].SetDirectory(0)
    
    tfile2.Close()

    return EECs1, EECs2

# %%
# smooth log version, no markers. 3.0mb over 0mb


ROOT.gDirectory.Clear()
EECs_3mb , EECs_0mb = ratio_initialise(filepath_3mb_nch60, filepath_0mb_nch60)

# pick out the histograms
ratio_60_71 = EECs_3mb["60 < Nch < 71"]
ratio_71_78 = EECs_3mb["71 < Nch < 78"]
ratio_78_91 = EECs_3mb["78 < Nch < 91"]
ratio_91_97 = EECs_3mb["91 < Nch < 97"]
ratio_97_1000 = EECs_3mb["97 < Nch < 1000"]

# divide by 0mb
ratio_60_71.Divide(EECs_0mb["60 < Nch < 71"])
ratio_71_78.Divide(EECs_0mb["71 < Nch < 78"])
ratio_78_91.Divide(EECs_0mb["78 < Nch < 91"])
ratio_91_97.Divide(EECs_0mb["91 < Nch < 97"])
ratio_97_1000.Divide(EECs_0mb["97 < Nch < 1000"])

# make tgrapherrors:
tgraph_ratio_60_71 = ROOT.TGraphErrors(ratio_60_71)
tgraph_ratio_71_78 = ROOT.TGraphErrors(ratio_71_78)
tgraph_ratio_78_91 = ROOT.TGraphErrors(ratio_78_91)
tgraph_ratio_91_97 = ROOT.TGraphErrors(ratio_91_97)
tgraph_ratio_97_1000 = ROOT.TGraphErrors(ratio_97_1000)


# Choosing colours:
tgraph_ratio_60_71.SetLineColorAlpha(colours[0], 0.7)
tgraph_ratio_71_78.SetLineColorAlpha(colours[1], 0.7)
tgraph_ratio_78_91.SetLineColorAlpha(colours[2], 0.7)
tgraph_ratio_91_97.SetLineColorAlpha(colours[3], 0.7)
tgraph_ratio_97_1000.SetLineColorAlpha(colours[4], 0.7)

tgraph_ratio_60_71.SetMarkerColorAlpha(colours[0], 0.7)
tgraph_ratio_71_78.SetMarkerColorAlpha(colours[1], 0.7)
tgraph_ratio_78_91.SetMarkerColorAlpha(colours[2], 0.7)
tgraph_ratio_91_97.SetMarkerColorAlpha(colours[3], 0.7)
tgraph_ratio_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

# if you don't want markers:
tgraph_ratio_60_71.SetMarkerStyle(1)
tgraph_ratio_71_78.SetMarkerStyle(1)
tgraph_ratio_78_91.SetMarkerStyle(1)
tgraph_ratio_91_97.SetMarkerStyle(1)
tgraph_ratio_97_1000.SetMarkerStyle(1)

tgraph_ratio_60_71.SetMarkerSize(0)
tgraph_ratio_71_78.SetMarkerSize(0)
tgraph_ratio_78_91.SetMarkerSize(0)
tgraph_ratio_91_97.SetMarkerSize(0)
tgraph_ratio_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_r", "ratios of EECs for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers - smooth, no error bars or markers
mg.Add(tgraph_ratio_60_71, "CX")
mg.Add(tgraph_ratio_71_78, "CX")
mg.Add(tgraph_ratio_78_91, "CX")
mg.Add(tgraph_ratio_91_97, "CX")
mg.Add(tgraph_ratio_97_1000, "CX")


# title
mg.SetTitle("EEC ratio for high multiplicity bins; #Delta R_{L}; E2C_{3.0mb} / E2C_{0mb}")
mg.Draw("A") 

# reference line
line = ROOT.TLine(0.001, 1.0, 1.0, 1.0)
line.SetLineStyle(2) # Dashed configuration
line.SetLineColor(ROOT.kBlack)
line.Draw()

# Log scale axes
canvas.SetLogx(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0, 2.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)


# Legend setup
legend = ROOT.TLegend(0.28, 0.24, 0.68, 0.44) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_ratio_60_71, "60 #leq N_{ch} < 71", "L")
legend.AddEntry(tgraph_ratio_71_78, "71 #leq N_{ch} < 78", "L")
legend.AddEntry(tgraph_ratio_78_91, "78 #leq N_{ch} < 91", "L")
legend.AddEntry(tgraph_ratio_91_97, "91 #leq N_{ch} < 97", "L")
legend.AddEntry(tgraph_ratio_97_1000, "97 #leq N_{ch} < 1000", "L")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_plot_ratio_3_0_smooth.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_plot_ratio_3_0.pdf has been created

# %%
# smooth log version, no markers. 3.0mb over 0mb , not smooth


ROOT.gDirectory.Clear()
EECs_3mb , EECs_0mb = ratio_initialise(filepath_3mb_nch60, filepath_0mb_nch60)

# pick out the histograms
ratio_60_71 = EECs_3mb["60 < Nch < 71"]
ratio_71_78 = EECs_3mb["71 < Nch < 78"]
ratio_78_91 = EECs_3mb["78 < Nch < 91"]
ratio_91_97 = EECs_3mb["91 < Nch < 97"]
ratio_97_1000 = EECs_3mb["97 < Nch < 1000"]

# divide by 0mb
ratio_60_71.Divide(EECs_0mb["60 < Nch < 71"])
ratio_71_78.Divide(EECs_0mb["71 < Nch < 78"])
ratio_78_91.Divide(EECs_0mb["78 < Nch < 91"])
ratio_91_97.Divide(EECs_0mb["91 < Nch < 97"])
ratio_97_1000.Divide(EECs_0mb["97 < Nch < 1000"])

# make tgrapherrors:
tgraph_ratio_60_71 = ROOT.TGraphErrors(ratio_60_71)
tgraph_ratio_71_78 = ROOT.TGraphErrors(ratio_71_78)
tgraph_ratio_78_91 = ROOT.TGraphErrors(ratio_78_91)
tgraph_ratio_91_97 = ROOT.TGraphErrors(ratio_91_97)
tgraph_ratio_97_1000 = ROOT.TGraphErrors(ratio_97_1000)


# Choosing colours:
tgraph_ratio_60_71.SetLineColorAlpha(colours[0], 0.7)
tgraph_ratio_71_78.SetLineColorAlpha(colours[1], 0.7)
tgraph_ratio_78_91.SetLineColorAlpha(colours[2], 0.7)
tgraph_ratio_91_97.SetLineColorAlpha(colours[3], 0.7)
tgraph_ratio_97_1000.SetLineColorAlpha(colours[4], 0.7)

tgraph_ratio_60_71.SetMarkerColorAlpha(colours[0], 0.7)
tgraph_ratio_71_78.SetMarkerColorAlpha(colours[1], 0.7)
tgraph_ratio_78_91.SetMarkerColorAlpha(colours[2], 0.7)
tgraph_ratio_91_97.SetMarkerColorAlpha(colours[3], 0.7)
tgraph_ratio_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

# if you don't want markers:
tgraph_ratio_60_71.SetMarkerStyle(1)
tgraph_ratio_71_78.SetMarkerStyle(1)
tgraph_ratio_78_91.SetMarkerStyle(1)
tgraph_ratio_91_97.SetMarkerStyle(1)
tgraph_ratio_97_1000.SetMarkerStyle(1)

tgraph_ratio_60_71.SetMarkerSize(0)
tgraph_ratio_71_78.SetMarkerSize(0)
tgraph_ratio_78_91.SetMarkerSize(0)
tgraph_ratio_91_97.SetMarkerSize(0)
tgraph_ratio_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_r", "ratios of EECs for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers - NOT smooth, no error bars or markers
mg.Add(tgraph_ratio_60_71, "LX")
mg.Add(tgraph_ratio_71_78, "LX")
mg.Add(tgraph_ratio_78_91, "LX")
mg.Add(tgraph_ratio_91_97, "LX")
mg.Add(tgraph_ratio_97_1000, "LX")


# title
mg.SetTitle("EEC ratio for high multiplicity bins; #Delta R_{L}; E2C_{3.0mb} / E2C_{0mb}")
mg.Draw("A") 

# reference line
line = ROOT.TLine(0.001, 1.0, 1.0, 1.0)
line.SetLineStyle(2) # Dashed configuration
line.SetLineColor(ROOT.kBlack)
line.Draw()

# Log scale axes
canvas.SetLogx(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0, 2.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)


# Legend setup
legend = ROOT.TLegend(0.28, 0.24, 0.68, 0.44) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_ratio_60_71, "60 #leq N_{ch} < 71", "L")
legend.AddEntry(tgraph_ratio_71_78, "71 #leq N_{ch} < 78", "L")
legend.AddEntry(tgraph_ratio_78_91, "78 #leq N_{ch} < 91", "L")
legend.AddEntry(tgraph_ratio_91_97, "91 #leq N_{ch} < 97", "L")
legend.AddEntry(tgraph_ratio_97_1000, "97 #leq N_{ch} < 1000", "L")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_plot_ratio_3_0.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_plot_ratio_3_0.pdf has been created

# %%
# log version, WITH markers. 3.0mb over 0mb


ROOT.gDirectory.Clear()
EECs_3mb , EECs_0mb = ratio_initialise(filepath_3mb_nch60, filepath_0mb_nch60)

# pick out the histograms
ratio_60_71 = EECs_3mb["60 < Nch < 71"]
ratio_71_78 = EECs_3mb["71 < Nch < 78"]
ratio_78_91 = EECs_3mb["78 < Nch < 91"]
ratio_91_97 = EECs_3mb["91 < Nch < 97"]
ratio_97_1000 = EECs_3mb["97 < Nch < 1000"]

# divide by 0mb
ratio_60_71.Divide(EECs_0mb["60 < Nch < 71"])
ratio_71_78.Divide(EECs_0mb["71 < Nch < 78"])
ratio_78_91.Divide(EECs_0mb["78 < Nch < 91"])
ratio_91_97.Divide(EECs_0mb["91 < Nch < 97"])
ratio_97_1000.Divide(EECs_0mb["97 < Nch < 1000"])

# make tgrapherrors:
tgraph_ratio_60_71 = ROOT.TGraphErrors(ratio_60_71)
tgraph_ratio_71_78 = ROOT.TGraphErrors(ratio_71_78)
tgraph_ratio_78_91 = ROOT.TGraphErrors(ratio_78_91)
tgraph_ratio_91_97 = ROOT.TGraphErrors(ratio_91_97)
tgraph_ratio_97_1000 = ROOT.TGraphErrors(ratio_97_1000)

# set markers:
tgraph_ratio_60_71.SetMarkerStyle(20)
tgraph_ratio_71_78.SetMarkerStyle(20)
tgraph_ratio_78_91.SetMarkerStyle(20)
tgraph_ratio_91_97.SetMarkerStyle(20)
tgraph_ratio_97_1000.SetMarkerStyle(20)

tgraph_ratio_60_71.SetMarkerSize(0.4)
tgraph_ratio_71_78.SetMarkerSize(0.4)
tgraph_ratio_78_91.SetMarkerSize(0.4)
tgraph_ratio_91_97.SetMarkerSize(0.4)
tgraph_ratio_97_1000.SetMarkerSize(0.4)

tgraph_ratio_60_71.SetLineWidth(1)
tgraph_ratio_71_78.SetLineWidth(1)
tgraph_ratio_78_91.SetLineWidth(1)
tgraph_ratio_91_97.SetLineWidth(1)
tgraph_ratio_97_1000.SetLineWidth(1)

# Choosing colours:
tgraph_ratio_60_71.SetLineColorAlpha(colours[0], 0.5)
tgraph_ratio_71_78.SetLineColorAlpha(colours[1], 0.5)
tgraph_ratio_78_91.SetLineColorAlpha(colours[2], 0.5)
tgraph_ratio_91_97.SetLineColorAlpha(colours[3], 0.5)
tgraph_ratio_97_1000.SetLineColorAlpha(colours[4], 0.5)

tgraph_ratio_60_71.SetMarkerColorAlpha(colours[0], 0.7)
tgraph_ratio_71_78.SetMarkerColorAlpha(colours[1], 0.7)
tgraph_ratio_78_91.SetMarkerColorAlpha(colours[2], 0.7)
tgraph_ratio_91_97.SetMarkerColorAlpha(colours[3], 0.7)
tgraph_ratio_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_r", "ratios of EECs for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers 
mg.Add(tgraph_ratio_60_71, "PE")
mg.Add(tgraph_ratio_71_78, "PE")
mg.Add(tgraph_ratio_78_91, "PE")
mg.Add(tgraph_ratio_91_97, "PE")
mg.Add(tgraph_ratio_97_1000, "PE")


# title
mg.SetTitle("EEC ratio for high multiplicity bins; #Delta R_{L}; E2C_{3.0mb} / E2C_{0mb}")
mg.Draw("A") 

# reference line
line = ROOT.TLine(0.001, 1.0, 1.0, 1.0)
line.SetLineStyle(2) # Dashed configuration
line.SetLineColor(ROOT.kBlack)
line.Draw()

# Log scale axes
canvas.SetLogx(1)
mg.GetXaxis().SetLimits(0.001, 1.0)
mg.GetYaxis().SetLimits(0, 2.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)


# Legend setup
legend = ROOT.TLegend(0.28, 0.24, 0.68, 0.44) 
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_ratio_60_71, "60 #leq N_{ch} < 71", "PE")
legend.AddEntry(tgraph_ratio_71_78, "71 #leq N_{ch} < 78", "PE")
legend.AddEntry(tgraph_ratio_78_91, "78 #leq N_{ch} < 91", "PE")
legend.AddEntry(tgraph_ratio_91_97, "91 #leq N_{ch} < 97", "PE")
legend.AddEntry(tgraph_ratio_97_1000, "97 #leq N_{ch} < 1000", "PE")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_plot_ratio_3_0_markers.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_plot_ratio_3_0_markers.pdf has been created

# %%
# smooth, no markers, non log version, 3.0 mb over 0mb

ROOT.gDirectory.Clear()
EECs_3mb , EECs_0mb = ratio_initialise(filepath_3mb_nch60, filepath_0mb_nch60)

# pick out the histograms
ratio_60_71 = EECs_3mb["60 < Nch < 71"]
ratio_71_78 = EECs_3mb["71 < Nch < 78"]
ratio_78_91 = EECs_3mb["78 < Nch < 91"]
ratio_91_97 = EECs_3mb["91 < Nch < 97"]
ratio_97_1000 = EECs_3mb["97 < Nch < 1000"]

# divide by 0mb
ratio_60_71.Divide(EECs_0mb["60 < Nch < 71"])
ratio_71_78.Divide(EECs_0mb["71 < Nch < 78"])
ratio_78_91.Divide(EECs_0mb["78 < Nch < 91"])
ratio_91_97.Divide(EECs_0mb["91 < Nch < 97"])
ratio_97_1000.Divide(EECs_0mb["97 < Nch < 1000"])

# make tgrapherrors:
tgraph_ratio_60_71 = ROOT.TGraphErrors(ratio_60_71)
tgraph_ratio_71_78 = ROOT.TGraphErrors(ratio_71_78)
tgraph_ratio_78_91 = ROOT.TGraphErrors(ratio_78_91)
tgraph_ratio_91_97 = ROOT.TGraphErrors(ratio_91_97)
tgraph_ratio_97_1000 = ROOT.TGraphErrors(ratio_97_1000)


# Choosing colours:
tgraph_ratio_60_71.SetLineColorAlpha(colours[0], 0.7)
tgraph_ratio_71_78.SetLineColorAlpha(colours[1], 0.7)
tgraph_ratio_78_91.SetLineColorAlpha(colours[2], 0.7)
tgraph_ratio_91_97.SetLineColorAlpha(colours[3], 0.7)
tgraph_ratio_97_1000.SetLineColorAlpha(colours[4], 0.7)

tgraph_ratio_60_71.SetMarkerColorAlpha(colours[0], 0.7)
tgraph_ratio_71_78.SetMarkerColorAlpha(colours[1], 0.7)
tgraph_ratio_78_91.SetMarkerColorAlpha(colours[2], 0.7)
tgraph_ratio_91_97.SetMarkerColorAlpha(colours[3], 0.7)
tgraph_ratio_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

# if you don't want markers:
tgraph_ratio_60_71.SetMarkerStyle(1)
tgraph_ratio_71_78.SetMarkerStyle(1)
tgraph_ratio_78_91.SetMarkerStyle(1)
tgraph_ratio_91_97.SetMarkerStyle(1)
tgraph_ratio_97_1000.SetMarkerStyle(1)

tgraph_ratio_60_71.SetMarkerSize(0)
tgraph_ratio_71_78.SetMarkerSize(0)
tgraph_ratio_78_91.SetMarkerSize(0)
tgraph_ratio_91_97.SetMarkerSize(0)
tgraph_ratio_97_1000.SetMarkerSize(0)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_r", "ratios of EECs for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers - smooth, no error bars or markers
mg.Add(tgraph_ratio_60_71, "CX")
mg.Add(tgraph_ratio_71_78, "CX")
mg.Add(tgraph_ratio_78_91, "CX")
mg.Add(tgraph_ratio_91_97, "CX")
mg.Add(tgraph_ratio_97_1000, "CX")


# title
mg.SetTitle("EEC ratio for high multiplicity bins; #Delta R_{L}; E2C_{3.0mb} / E2C_{0mb}")
mg.Draw("A") 

# reference line
line = ROOT.TLine(0, 1.0, 1.0, 1.0)
line.SetLineStyle(2) # Dashed configuration
line.SetLineColor(ROOT.kBlack)
line.Draw()

# normal scale axes
mg.GetXaxis().SetLimits(0, 1.0)
mg.GetYaxis().SetLimits(0, 2.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)


# Legend setup
legend = ROOT.TLegend(0.48, 0.68, 0.88, 0.88)
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_ratio_60_71, "60 #leq N_{ch} < 71", "L")
legend.AddEntry(tgraph_ratio_71_78, "71 #leq N_{ch} < 78", "L")
legend.AddEntry(tgraph_ratio_78_91, "78 #leq N_{ch} < 91", "L")
legend.AddEntry(tgraph_ratio_91_97, "91 #leq N_{ch} < 97", "L")
legend.AddEntry(tgraph_ratio_97_1000, "97 #leq N_{ch} < 1000", "L")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_plot_ratio_3_0_nonlog.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_plot_ratio_3_0_nonlog.pdf has been created

# %%
# NON log version, WITH markers. 3.0mb over 0mb


ROOT.gDirectory.Clear()
EECs_3mb , EECs_0mb = ratio_initialise(filepath_3mb_nch60, filepath_0mb_nch60)

# pick out the histograms
ratio_60_71 = EECs_3mb["60 < Nch < 71"]
ratio_71_78 = EECs_3mb["71 < Nch < 78"]
ratio_78_91 = EECs_3mb["78 < Nch < 91"]
ratio_91_97 = EECs_3mb["91 < Nch < 97"]
ratio_97_1000 = EECs_3mb["97 < Nch < 1000"]

# divide by 0mb
ratio_60_71.Divide(EECs_0mb["60 < Nch < 71"])
ratio_71_78.Divide(EECs_0mb["71 < Nch < 78"])
ratio_78_91.Divide(EECs_0mb["78 < Nch < 91"])
ratio_91_97.Divide(EECs_0mb["91 < Nch < 97"])
ratio_97_1000.Divide(EECs_0mb["97 < Nch < 1000"])

# make tgrapherrors:
tgraph_ratio_60_71 = ROOT.TGraphErrors(ratio_60_71)
tgraph_ratio_71_78 = ROOT.TGraphErrors(ratio_71_78)
tgraph_ratio_78_91 = ROOT.TGraphErrors(ratio_78_91)
tgraph_ratio_91_97 = ROOT.TGraphErrors(ratio_91_97)
tgraph_ratio_97_1000 = ROOT.TGraphErrors(ratio_97_1000)

# set markers:
tgraph_ratio_60_71.SetMarkerStyle(20)
tgraph_ratio_71_78.SetMarkerStyle(20)
tgraph_ratio_78_91.SetMarkerStyle(20)
tgraph_ratio_91_97.SetMarkerStyle(20)
tgraph_ratio_97_1000.SetMarkerStyle(20)

tgraph_ratio_60_71.SetMarkerSize(0.4)
tgraph_ratio_71_78.SetMarkerSize(0.4)
tgraph_ratio_78_91.SetMarkerSize(0.4)
tgraph_ratio_91_97.SetMarkerSize(0.4)
tgraph_ratio_97_1000.SetMarkerSize(0.4)

tgraph_ratio_60_71.SetLineWidth(1)
tgraph_ratio_71_78.SetLineWidth(1)
tgraph_ratio_78_91.SetLineWidth(1)
tgraph_ratio_91_97.SetLineWidth(1)
tgraph_ratio_97_1000.SetLineWidth(1)

# Choosing colours:
tgraph_ratio_60_71.SetLineColorAlpha(colours[0], 0.5)
tgraph_ratio_71_78.SetLineColorAlpha(colours[1], 0.5)
tgraph_ratio_78_91.SetLineColorAlpha(colours[2], 0.5)
tgraph_ratio_91_97.SetLineColorAlpha(colours[3], 0.5)
tgraph_ratio_97_1000.SetLineColorAlpha(colours[4], 0.5)

tgraph_ratio_60_71.SetMarkerColorAlpha(colours[0], 0.7)
tgraph_ratio_71_78.SetMarkerColorAlpha(colours[1], 0.7)
tgraph_ratio_78_91.SetMarkerColorAlpha(colours[2], 0.7)
tgraph_ratio_91_97.SetMarkerColorAlpha(colours[3], 0.7)
tgraph_ratio_97_1000.SetMarkerColorAlpha(colours[4], 0.7)

# initialise canvas
canvas = ROOT.TCanvas("c_eec_r", "ratios of EECs for different multiplicity bins", 750, 650)

canvas.SetLeftMargin(0.15)
canvas.SetBottomMargin(0.15)
canvas.SetGrid()

transparent_grid = ROOT.TColor.GetColorTransparent(12, 0.4)
ROOT.gStyle.SetGridColor(transparent_grid)

# initialise multigraph
mg = ROOT.TMultiGraph()

# Add the data markers
mg.Add(tgraph_ratio_60_71, "PE")
mg.Add(tgraph_ratio_71_78, "PE")
mg.Add(tgraph_ratio_78_91, "PE")
mg.Add(tgraph_ratio_91_97, "PE")
mg.Add(tgraph_ratio_97_1000, "PE")


# title
mg.SetTitle("EEC ratio for high multiplicity bins; #Delta R_{L}; E2C_{3.0mb} / E2C_{0mb}")
mg.Draw("A") 

# reference line
line = ROOT.TLine(0, 1.0, 1.0, 1.0)
line.SetLineStyle(2) # Dashed configuration
line.SetLineColor(ROOT.kBlack)
line.Draw()

# regular axes
mg.GetXaxis().SetLimits(0, 1.0)
mg.GetYaxis().SetLimits(0, 2.0)

mg.GetXaxis().SetTitleSize(0.045)
mg.GetYaxis().SetTitleSize(0.045)
mg.GetXaxis().SetLabelSize(0.04)
mg.GetYaxis().SetLabelSize(0.04)


# Legend setup
legend = ROOT.TLegend(0.48, 0.68, 0.88, 0.88)
legend.SetBorderSize(0)
legend.SetFillStyle(0) 
legend.SetTextSize(0.035)
legend.AddEntry(tgraph_ratio_60_71, "60 #leq N_{ch} < 71", "PE")
legend.AddEntry(tgraph_ratio_71_78, "71 #leq N_{ch} < 78", "PE")
legend.AddEntry(tgraph_ratio_78_91, "78 #leq N_{ch} < 91", "PE")
legend.AddEntry(tgraph_ratio_91_97, "91 #leq N_{ch} < 97", "PE")
legend.AddEntry(tgraph_ratio_97_1000, "97 #leq N_{ch} < 1000", "PE")
legend.Draw()

canvas.Update()
canvas.SaveAs("EEC_plot_ratio_3_0_markers_nonlog.pdf")
canvas.Close()
# Out:
# Info in <TCanvas::Print>: pdf file EEC_plot_ratio_3_0_markers_nonlog.pdf has been created
